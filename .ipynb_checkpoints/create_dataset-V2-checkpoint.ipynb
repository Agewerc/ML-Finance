# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import re

# %% [markdown]
# #### Import Datasets

# %%
df_ratings = pd.read_csv('stocks_us/ratings-history.csv')
df_is_stocks = pd.read_csv('stocks_us/us_stocks.csv')

# %%
rating_set = {'A', 'A+', 'A-', 'AA', 'AA-', 'AAA', 
              'B', 'B+', 'B-', 'BB', 'BB+', 'BB-', 'BBB', 'BBB+', 'BBB-',
              'CC', 'CCC', 'CCC+', 'CCC-', 'D'}

# %%
df_ratings = df_ratings[df_ratings['Rating'].isin(rating_set)]

# %%
df_ratings = df_ratings.drop_duplicates(subset = df_ratings.columns)

# %%
df_ratings['Rating'] = df_ratings['Rating'].str.replace(r'+', '').str.replace(r'-', '')

# %%
df_ratings.groupby('Rating').count()
# Out:
#         Rating Agency Name   Name  Rating Outlook   date
# Rating
# A                     6683   6683            5505   6683
# AA                    1106   1106             941   1106
# AAA                    130    130             124    130
# B                    16418  16418           13964  16418
# BB                    9840   9840            8150   9840
# BBB                  13398  13398           10822  13398
# CC                     296    296             199    296
# CCC                   2150   2150            1704   2150
# D                      280    280             196    280

# %% [markdown]
# ## Clean Company Names

# %%
df_is_stocks['Clean_Name'] = df_is_stocks['Name']
df_ratings['Clean_Name'] = df_ratings['Name']

# %%
def clean(company_name):
    
    name = company_name.lower()
    name = re.sub(r'\.', '', name)
    name = re.sub(r',', '', name)
    name = re.sub(r'^a-z', '', name)
    name = re.sub(r'corporation', '', name)
    name = re.sub(r' corp', '', name)    
    name = re.sub(r' co', '', name)   
    name = re.sub(r'inc', '', name)
    name = re.sub(r'limited', '', name)
    name = re.sub(r'ltd', '', name)
    name = re.sub(r'holdings', '', name)
    name = re.sub(r' holding', '', name)    
    name = re.sub(r'plc', '', name)
    name = re.sub(r'group', '', name)
    name = re.sub(r' ag', '', name)
    name = re.sub(r' sa', '', name)
    name = re.sub(r' pty', '', name)
    name = re.sub(r' international', '', name)
    name = re.sub(r' incorporated', '', name)
    name = re.sub(r' spa', '', name)
    name = re.sub(r' se', '', name)
    name = re.sub(r' lp', '', name)    
    name = re.sub(r' (The)', '', name)    
    name = re.sub(r'The', '', name)    
    name = re.sub(r'LLC', '', name)   
    name = re.sub(r'n.v', '', name)   
    name = name.strip()
    return name

# %%
df_is_stocks['Clean_Name'] = df_is_stocks['Name'].apply(clean)
df_ratings['Clean_Name'] = df_ratings['Clean_Name'].apply(clean)

# %%
df_is_stocks[df_is_stocks['Clean_Name'] =='microsoft ']
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, Sector, industry, Clean_Name]
# Index: []

# %%
df_ratings[df_ratings['Rating'] == 'AAA'].head(30)
# Out:
#                        Rating Agency Name  \
# 848    Standard & Poor's Ratings Services
# 2445   Standard & Poor's Ratings Services
# 2543   Standard & Poor's Ratings Services
# 2991   Standard & Poor's Ratings Services
# 3188   Standard & Poor's Ratings Services
# 4118   Standard & Poor's Ratings Services
# 4366   Standard & Poor's Ratings Services
# 4642   Standard & Poor's Ratings Services
# 5308   Standard & Poor's Ratings Services
# 6405   Standard & Poor's Ratings Services
# 8116   Standard & Poor's Ratings Services
# 8211   Standard & Poor's Ratings Services
# 8727   Standard & Poor's Ratings Services
# 8869   Standard & Poor's Ratings Services
# 9946   Standard & Poor's Ratings Services
# 10373  Standard & Poor's Ratings Services
# 10969  Standard & Poor's Ratings Services
# 11013  Standard & Poor's Ratings Services
# 11248  Standard & Poor's Ratings Services
# 11713  Standard & Poor's Ratings Services
# 12740  Standard & Poor's Ratings Services
# 12810  Standard & Poor's Ratings Services
# 12909  Standard & Poor's Ratings Services
# 13461  Standard & Poor's Ratings Services
# 13559  Standard & Poor's Ratings Services
# 13919  Standard & Poor's Ratings Services
# 14186  Standard & Poor's Ratings Services
# 14669  Standard & Poor's Ratings Services
# 14673  Standard & Poor's Ratings Services
# 15620  Standard & Poor's Ratings Services
#
#                                           Name Rating Rating Outlook  \
# 848                            Microsoft Corp.    AAA         Stable
# 2445                         Johnson & Johnson    AAA         Stable
# 2543        Temasek Holdings (Private) Limited    AAA         Stable
# 2991                         Exxon Mobil Corp.    AAA         Stable
# 3188        Temasek Holdings (Private) Limited    AAA         Stable
# 4118                         Imperial Oil Ltd.    AAA         Stable
# 4366      SeaRiver Maritime Financial Holdings    AAA         Stable
# 4642   Singapore Technologies Engineering Ltd.    AAA         Stable
# 5308               Airport Authority Hong Kong    AAA         Stable
# 6405                   Urban Renewal Authority    AAA         Stable
# 8116                                  EBN B.V.    AAA       Negative
# 8211        Temasek Holdings (Private) Limited    AAA         Stable
# 8727                   Urban Renewal Authority    AAA         Stable
# 8869                         Johnson & Johnson    AAA         Stable
# 9946                         Imperial Oil Ltd.    AAA         Stable
# 10373                        Exxon Mobil Corp.    AAA         Stable
# 10969                              Mobil Corp.    AAA         Stable
# 11013       Temasek Holdings (Private) Limited    AAA         Stable
# 11248                           MTR Corp. Ltd.    AAA         Stable
# 11713                    Airservices Australia    AAA         Stable
# 12740           Automatic Data Processing Inc.    AAA         Stable
# 12810                        Imperial Oil Ltd.    AAA         Stable
# 12909              Airport Authority Hong Kong    AAA         Stable
# 13461  Singapore Technologies Engineering Ltd.    AAA         Stable
# 13559                              Mobil Corp.    AAA         Stable
# 13919                          Microsoft Corp.    AAA         Stable
# 14186                          Microsoft Corp.    AAA         Stable
# 14669           Automatic Data Processing Inc.    AAA         Stable
# 14673                        Imperial Oil Ltd.    AAA         Stable
# 15620                        Exxon Mobil Corp.    AAA         Stable
#
#              date                          Clean_Name
# 848    11/23/2010                           microsoft
# 2445    9/26/2011                   johnson & johnson
# 2543   12/14/2015                  temasek  (private)
# 2991    9/30/2013                         exxon mobil
# 3188    9/17/2013                  temasek  (private)
# 4118     5/6/2010                        imperial oil
# 4366     7/7/2015         seariver maritime financial
# 4642    8/28/2014  singapore technologies engineering
# 5308    12/7/2011         airport authority hong kong
# 6405    2/16/2015             urban renewal authority
# 8116   10/26/2012                              ebn bv
# 8211    2/16/2011                  temasek  (private)
# 8727     4/1/2014             urban renewal authority
# 8869   10/22/2015                   johnson & johnson
# 9946    1/16/2015                        imperial oil
# 10373  12/29/2010                         exxon mobil
# 10969  12/23/2011                               mobil
# 11013   10/5/2011                  temasek  (private)
# 11248    9/1/2015                                 mtr
# 11713  12/17/2015               airservices australia
# 12740   7/30/2013           automatic data processing
# 12810   11/7/2014                        imperial oil
# 12909   9/30/2014         airport authority hong kong
# 13461   8/29/2011  singapore technologies engineering
# 13559   1/16/2015                               mobil
# 13919  11/16/2012                           microsoft
# 14186   8/18/2015                           microsoft
# 14669   11/9/2011           automatic data processing
# 14673   1/31/2012                        imperial oil
# 15620  12/26/2012                         exxon mobil

# %%
df_ratings = pd.merge(df_ratings, df_is_stocks ,on='Clean_Name')

# %%
df_ratings = df_ratings.rename(columns = {'Name_x': 'Name'}).drop('Name_y', axis = 1)

# %%
df_ratings.groupby('Rating').count()
# Out:
#         Rating Agency Name  Name  Rating Outlook  date  Clean_Name  Symbol  \
# Rating
# A                     1779  1779            1297  1779        1779    1779
# AA                     208   208             141   208         208     208
# AAA                     39    39              35    39          39      39
# B                     1965  1965            1664  1965        1965    1965
# BB                    2922  2922            2505  2922        2922    2922
# BBB                   3899  3899            3002  3899        3899    3899
# CC                      21    21              16    21          21      21
# CCC                    229   229             179   229         229     229
# D                       22    22              15    22          22      22
#
#         Sector  industry
# Rating
# A         1491      1491
# AA         185       185
# AAA         39        39
# B         1802      1802
# BB        2600      2600
# BBB       3370      3370
# CC          19        19
# CCC        192       192
# D           18        18

# %%
len(df_ratings)
# Out:
# 11084

# %%
df_ratings[df_ratings['Rating'] == 'AAA']
# Out:
#                       Rating Agency Name                            Name  \
# 1634  Standard & Poor's Ratings Services                 Microsoft Corp.
# 1635  Standard & Poor's Ratings Services                 Microsoft Corp.
# 1636  Standard & Poor's Ratings Services                 Microsoft Corp.
# 1637  Standard & Poor's Ratings Services                 Microsoft Corp.
# 1638  Standard & Poor's Ratings Services                 Microsoft Corp.
# 1639  Standard & Poor's Ratings Services                 Microsoft Corp.
# 1640  Standard & Poor's Ratings Services                 Microsoft Corp.
# 1641  Standard & Poor's Ratings Services                 Microsoft Corp.
# 4061  Standard & Poor's Ratings Services               Johnson & Johnson
# 4062  Standard & Poor's Ratings Services               Johnson & Johnson
# 4063  Standard & Poor's Ratings Services               Johnson & Johnson
# 4064  Standard & Poor's Ratings Services               Johnson & Johnson
# 4065  Standard & Poor's Ratings Services               Johnson & Johnson
# 4066  Standard & Poor's Ratings Services               Johnson & Johnson
# 4067  Standard & Poor's Ratings Services               Johnson & Johnson
# 4068                       Fitch Ratings               Johnson & Johnson
# 4827  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4828  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4829  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4830  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4831  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4832  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4833  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4834  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4835  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4836  Standard & Poor's Ratings Services               Exxon Mobil Corp.
# 4837    Morningstar Credit Ratings, LLC.                Exxon Mobil Corp
# 5870  Standard & Poor's Ratings Services               Imperial Oil Ltd.
# 5871  Standard & Poor's Ratings Services               Imperial Oil Ltd.
# 5872  Standard & Poor's Ratings Services               Imperial Oil Ltd.
# 5873  Standard & Poor's Ratings Services               Imperial Oil Ltd.
# 5874  Standard & Poor's Ratings Services               Imperial Oil Ltd.
# 5875  Standard & Poor's Ratings Services               Imperial Oil Ltd.
# 5876  Standard & Poor's Ratings Services               Imperial Oil Ltd.
# 5877  Standard & Poor's Ratings Services               Imperial Oil Ltd.
# 9544  Standard & Poor's Ratings Services  Automatic Data Processing Inc.
# 9545  Standard & Poor's Ratings Services  Automatic Data Processing Inc.
# 9549  Standard & Poor's Ratings Services  Automatic Data Processing Inc.
# 9550  Standard & Poor's Ratings Services  Automatic Data Processing Inc.
#
#      Rating Rating Outlook        date                 Clean_Name Symbol  \
# 1634    AAA         Stable  11/23/2010                  microsoft   MSFT
# 1635    AAA         Stable  11/16/2012                  microsoft   MSFT
# 1636    AAA         Stable   8/18/2015                  microsoft   MSFT
# 1637    AAA         Stable   6/13/2016                  microsoft   MSFT
# 1638    AAA         Stable    8/6/2013                  microsoft   MSFT
# 1639    AAA         Stable   8/15/2016                  microsoft   MSFT
# 1640    AAA         Stable   11/3/2011                  microsoft   MSFT
# 1641    AAA         Stable   8/20/2014                  microsoft   MSFT
# 4061    AAA         Stable   9/26/2011          johnson & johnson    JNJ
# 4062    AAA         Stable  10/22/2015          johnson & johnson    JNJ
# 4063    AAA         Stable   9/18/2012          johnson & johnson    JNJ
# 4064    AAA         Stable  10/28/2016          johnson & johnson    JNJ
# 4065    AAA         Stable   11/4/2010          johnson & johnson    JNJ
# 4066    AAA         Stable  11/25/2014          johnson & johnson    JNJ
# 4067    AAA         Stable   9/25/2013          johnson & johnson    JNJ
# 4068    AAA            NaN   6/15/2012          johnson & johnson    JNJ
# 4827    AAA         Stable   9/30/2013                exxon mobil    XOM
# 4828    AAA         Stable  12/29/2010                exxon mobil    XOM
# 4829    AAA         Stable  12/26/2012                exxon mobil    XOM
# 4830    AAA         Stable  12/23/2011                exxon mobil    XOM
# 4831    AAA         Stable   1/16/2015                exxon mobil    XOM
# 4832    AAA         Stable   9/26/2014                exxon mobil    XOM
# 4833    AAA            NaN    2/2/2016                exxon mobil    XOM
# 4834    AAA         Stable   9/21/2015                exxon mobil    XOM
# 4835    AAA       Negative   10/2/2015                exxon mobil    XOM
# 4836    AAA         Stable   5/27/2015                exxon mobil    XOM
# 4837    AAA            NaN  11/18/2009                exxon mobil    XOM
# 5870    AAA         Stable    5/6/2010               imperial oil    IMO
# 5871    AAA         Stable   1/16/2015               imperial oil    IMO
# 5872    AAA         Stable   11/7/2014               imperial oil    IMO
# 5873    AAA         Stable   1/31/2012               imperial oil    IMO
# 5874    AAA         Stable   9/30/2013               imperial oil    IMO
# 5875    AAA         Stable    8/7/2015               imperial oil    IMO
# 5876    AAA            NaN    2/2/2016               imperial oil    IMO
# 5877    AAA       Negative   10/5/2015               imperial oil    IMO
# 9544    AAA         Stable   7/30/2013  automatic data processing    ADP
# 9545    AAA         Stable   11/9/2011  automatic data processing    ADP
# 9549    AAA         Stable   9/16/2010  automatic data processing    ADP
# 9550    AAA         Stable  12/18/2012  automatic data processing    ADP
#
#            Sector                                 industry
# 1634   Technology  Computer Software: Prepackaged Software
# 1635   Technology  Computer Software: Prepackaged Software
# 1636   Technology  Computer Software: Prepackaged Software
# 1637   Technology  Computer Software: Prepackaged Software
# 1638   Technology  Computer Software: Prepackaged Software
# 1639   Technology  Computer Software: Prepackaged Software
# 1640   Technology  Computer Software: Prepackaged Software
# 1641   Technology  Computer Software: Prepackaged Software
# 4061  Health Care                    Major Pharmaceuticals
# 4062  Health Care                    Major Pharmaceuticals
# 4063  Health Care                    Major Pharmaceuticals
# 4064  Health Care                    Major Pharmaceuticals
# 4065  Health Care                    Major Pharmaceuticals
# 4066  Health Care                    Major Pharmaceuticals
# 4067  Health Care                    Major Pharmaceuticals
# 4068  Health Care                    Major Pharmaceuticals
# 4827       Energy                 Integrated oil Companies
# 4828       Energy                 Integrated oil Companies
# 4829       Energy                 Integrated oil Companies
# 4830       Energy                 Integrated oil Companies
# 4831       Energy                 Integrated oil Companies
# 4832       Energy                 Integrated oil Companies
# 4833       Energy                 Integrated oil Companies
# 4834       Energy                 Integrated oil Companies
# 4835       Energy                 Integrated oil Companies
# 4836       Energy                 Integrated oil Companies
# 4837       Energy                 Integrated oil Companies
# 5870       Energy                 Integrated oil Companies
# 5871       Energy                 Integrated oil Companies
# 5872       Energy                 Integrated oil Companies
# 5873       Energy                 Integrated oil Companies
# 5874       Energy                 Integrated oil Companies
# 5875       Energy                 Integrated oil Companies
# 5876       Energy                 Integrated oil Companies
# 5877       Energy                 Integrated oil Companies
# 9544   Technology                             EDP Services
# 9545   Technology                             EDP Services
# 9549   Technology                             EDP Services
# 9550   Technology                             EDP Services

# %% [markdown]
# ## API Function get Data

# %%
#!/usr/bin/env python

try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import json

def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    
    response = urlopen(url)
    data = response.read().decode("utf-8")
    
    return json.loads(data)

# %% [markdown]
# ## Get Financial Data

# %%
Symbol_list = list(set(df_ratings.Symbol))

# %%
company_ratios = pd.DataFrame.from_dict(get_jsonparsed_data("https://financialmodelingprep.com/api/v3/ratios/" + Symbol_list[0] + 
                                                         "?apikey=c283e7eb3ddc10dcc0ed8146046dff97"))

company_ratios = company_ratios[0:0]

# %%
for Symbol in Symbol_list:
    
    if Symbol.isalpha() == True:
    
        ratios = pd.DataFrame.from_dict(get_jsonparsed_data("https://financialmodelingprep.com/api/v3/ratios/" + 
                                                             Symbol + "?apikey=c283e7eb3ddc10dcc0ed8146046dff97"))
    
        frames = [company_ratios, ratios]
    
        company_ratios = pd.concat(frames)

# %%
company_ratios.head()
# Out:
#   Symbol       date currentRatio quickRatio    cashRatio  \
# 0    DNR 2019-12-31     0.495854   0.416899   0.00141664
# 1    DNR 2018-12-31     0.812225   0.705682     0.105704
# 2    DNR 2017-12-31      0.44155   0.319593  0.000126622
# 3    DNR 2016-12-31     0.417826    0.29191   0.00370476
# 4    DNR 2015-12-31     0.924113   0.659681   0.00753857
#
#    daysOfSalesOutstanding daysOfInventoryOutstanding operatingCycle  \
# 0               39.910329                          0        39.9103
# 1               31.156244                          0        31.1562
# 2               47.276130                        NaN            NaN
# 3               46.742340                        NaN            NaN
# 4               29.144331                        NaN            NaN
#
#   daysOfPayablesOutstanding cashConversionCycle  ...  priceEarningsRatio  \
# 0                   140.603            -100.693  ...             2.11802
# 1                   147.857            -116.701  ...             2.82784
# 2                       NaN                 NaN  ...              5.8944
# 3                       NaN                 NaN  ...            -1.29065
# 4                       NaN                 NaN  ...           -0.124077
#
#    priceToFreeCashFlowsRatio  priceToOperatingCashFlowsRatio  \
# 0                   0.929941                        0.929941
# 1                     1.7228                          1.7228
# 2                    3.59988                         3.59988
# 3                    5.74714                         5.74714
# 4                    0.62956                         0.62956
#
#    priceCashFlowRatio priceEarningsToGrowthRatio  priceSalesRatio  \
# 0            0.929941                    3.01608         0.360444
# 1              1.7228                     3.7899         0.619248
# 2             3.59988                    7.14069         0.851208
# 3             5.74714                   -1.49527          1.29142
# 4             0.62956                  -0.134113         0.432688
#
#   dividendYield enterpriseValueMultiple priceFairValue  Year
# 0           NaN                 4.92373       0.325382  2019
# 1           NaN                 5.75903       0.799227  2018
# 2   0.000285957                  15.537         1.4837  2017
# 3   0.000385743                -6.41776        2.68953  2016
# 4      0.120239               -0.665779       0.435684  2015
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Merge Datasets

# %% [markdown]
# #### select dates

# %%
df_ratings['date'] = df_ratings['date'].astype('datetime64[ns]')
df_ratings['month_rating'] = df_ratings['date'].dt.month
df_ratings['year_change'] = [1 if x < 7 else 0 for x in df_ratings['month_rating']]
df_ratings['year'] = df_ratings['date'].dt.year

# %%
df_ratings['Year'] = df_ratings['year'] - df_ratings['year_change']

# %%
company_ratios = company_ratios.rename(columns = {'symbol':'Symbol'})

# %%
company_ratios['date'] = company_ratios['date'].astype('datetime64[ns]')
company_ratios['Year'] = company_ratios['date'].dt.year

# %%
df_ratings = pd.merge(df_ratings, company_ratios, on=['Symbol', 'Year'])

# %%
df_ratings.groupby('Rating').count()
# Out:
#         Rating Agency Name  Name  Rating Outlook  date_x  Clean_Name  Symbol  \
# Rating
# A                      854   854             625     854         854     854
# AA                     142   142             100     142         142     142
# AAA                     20    20              18      20          20      20
# B                      845   845             734     845         845     845
# BB                    1601  1601            1428    1601        1601    1601
# BBB                   1871  1871            1439    1871        1871    1871
# CC                      12    12               7      12          12      12
# CCC                     96    96              82      96          96      96
# D                        7     7               5       7           7       7
#
#         Sector  industry  month_rating  year_change  ...  priceToSalesRatio  \
# Rating                                               ...
# A          854       854           854          854  ...                688
# AA         142       142           142          142  ...                118
# AAA         20        20            20           20  ...                 17
# B          837       837           845          845  ...                738
# BB        1565      1565          1601         1601  ...               1431
# BBB       1853      1853          1871         1871  ...               1647
# CC          12        12            12           12  ...                  8
# CCC         96        96            96           96  ...                 84
# D            7         7             7            7  ...                  6
#
#         priceEarningsRatio  priceToFreeCashFlowsRatio  \
# Rating
# A                      682                        810
# AA                     112                        140
# AAA                     17                         19
# B                      725                        833
# BB                    1414                       1566
# BBB                   1624                       1824
# CC                       9                         12
# CCC                     80                         92
# D                        5                          6
#
#         priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# Rating
# A                                  697                 697
# AA                                 117                 117
# AAA                                 16                  16
# B                                  716                 716
# BB                                1404                1404
# BBB                               1641                1641
# CC                                   9                   9
# CCC                                 82                  82
# D                                    6                   6
#
#         priceEarningsToGrowthRatio  priceSalesRatio  dividendYield  \
# Rating
# A                              681              688            651
# AA                             112              118            103
# AAA                             17               17             16
# B                              719              738            314
# BB                            1397             1431            895
# BBB                           1612             1647           1410
# CC                               9                8              1
# CCC                             80               84             30
# D                                5                6              0
#
#         enterpriseValueMultiple  priceFairValue
# Rating
# A                           800             646
# AA                          141              94
# AAA                          20              17
# B                           839             705
# BB                         1586            1349
# BBB                        1809            1565
# CC                           12               9
# CCC                          94              83
# D                             6               6
#
# [9 rows x 67 columns]

# %%
df_ratings.to_csv (r'C:stocks_us/rating_dataframe.csv', index = False, header=True)
