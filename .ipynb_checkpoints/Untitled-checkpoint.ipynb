# %% [markdown]
# # Import Data

# %%
import pandas as pd

# %%
stocks = pd.read_csv('companies.csv')

# %%
ticker_list = list(set(stocks.Ticker))

# %%
company_all = pd.DataFrame.from_dict(get_jsonparsed_data("https://financialmodelingprep.com/api/v3/ratios/" + ticker_list[0] + 
                                                         "?apikey=c283e7eb3ddc10dcc0ed8146046dff97"))

company_all = company_all[0:0]

# %%
for ticker in ticker_list:
    
    company = pd.DataFrame.from_dict(get_jsonparsed_data("https://financialmodelingprep.com/api/v3/ratios/" + ticker + 
                                                         "?apikey=c283e7eb3ddc10dcc0ed8146046dff97"))

    frames = [company_all, company]
    
    company_all = pd.concat(frames)

# %%
company_all.to_csv('fin_companies.csv')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
company_all['date'] = company_all['date'].astype('datetime64[ns]')

# %%
company_all
# Out:
#    symbol       date currentRatio quickRatio cashRatio daysOfSalesOutstanding  \
# 0    WYNN 2019-12-31       1.4405     1.1861    1.1861                      0
# 1    WYNN 2018-12-31      1.40345     1.1769    1.1769                      0
# 2    WYNN 2017-12-31      1.77371    1.53927   1.45288                      0
# 3    WYNN 2016-12-31      2.11139    1.85452   1.73206                      0
# 4    WYNN 2015-12-31      2.25711    1.97752   1.87367                      0
# ..    ...        ...          ...        ...       ...                    ...
# 12     FL 2009-01-31      8.17112    2.18182   2.05882                    NaN
# 13     FL 2008-02-02      7.61373    2.11588   2.09442                    NaN
# 14     FL 2007-02-03      6.56667    1.74074  0.818519                    NaN
# 15     FL 2005-12-30      4.46845    1.42476  0.701456                    NaN
# 16     FL 2005-01-29      4.11779    1.23308   0.56391                    NaN
#
#    daysOfInventoryOutstanding operatingCycle daysOfPayablesOutstanding  \
# 0                     11.0488        11.0488                   32.7569
# 1                     39.7558        39.7558                   192.013
# 2                     63.6454        63.6454                   253.598
# 3                     89.0443        89.0443                   290.364
# 4                     75.2671        75.2671                   212.558
# ..                        ...            ...                       ...
# 12                    108.234            NaN                   18.0712
# 13                    116.397            NaN                   21.1713
# 14                    118.484            NaN                   23.2785
# 15                    116.052            NaN                    33.409
# 16                    112.873            NaN                    37.363
#
#    cashConversionCycle  ... priceToSalesRatio priceEarningsRatio  \
# 0             -32.7569  ...           2.95502              109.9
# 1             -192.013  ...           1.91058            22.4213
# 2             -253.598  ...           2.77401            23.4133
# 3             -290.364  ...           2.32926            42.9928
# 4             -212.558  ...           1.67137            34.8831
# ..                 ...  ...               ...                ...
# 12                 NaN  ...               NaN           -15.9653
# 13                 NaN  ...               NaN              38.25
# 14                 NaN  ...               NaN            14.1006
# 15                 NaN  ...               NaN            13.1706
# 16                 NaN  ...               NaN            16.1538
#
#    priceToFreeCashFlowsRatio priceToOperatingCashFlowsRatio  \
# 0                 -83.317729                             15
# 1                 -24.946624                        13.3487
# 2                  18.588772                        9.32227
# 3                 -40.733387                        10.7189
# 4                  -5.052047                        11.8927
# ..                       ...                            ...
# 12                  3.293107                        3.29311
# 13                  6.893110                        6.89311
# 14                 18.726232                        18.7262
# 15                  9.822134                        9.82213
# 16                 16.377429                        16.3774
#
#    priceCashFlowRatio  priceEarningsToGrowthRatio priceSalesRatio  \
# 0                  15                     20.4938         2.95502
# 1             13.3487                     4.17259         1.91058
# 2             9.32227                     4.17486         2.77401
# 3             10.7189                     7.61911         2.32926
# 4             11.8927                     6.16473         1.67137
# ..                ...                         ...             ...
# 12            3.29311                    -4.54466             NaN
# 13            6.89311                     11.2682             NaN
# 14            18.7262                     4.11451             NaN
# 15            9.82213                     3.78062             NaN
# 16            16.3774                     5.17678             NaN
#
#    dividendYield enterpriseValueMultiple priceFairValue
# 0      0.0419147                 14.0767        7.75428
# 1      0.0443941                 15.1488        6.30965
# 2      0.0183355                 14.8922        18.4565
# 3      0.0312613                 19.0124        65.8642
# 4      0.0732654                 13.9279       -60.8357
# ..           ...                     ...            ...
# 12     0.0737358                 19.9659            NaN
# 13      0.039472                  7.8314            NaN
# 14     0.0172353                 7.92952            NaN
# 15     0.0140925                 7.58073            NaN
# 16    0.00823988                 11.1102            NaN
#
# [6173 rows x 56 columns]

# %%
#!/usr/bin/env python

try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import json

def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url)
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://financialmodelingprep.com/api/v3/ratios/BCE?apikey=c283e7eb3ddc10dcc0ed8146046dff97")
BCE = get_jsonparsed_data(url)

# %%
BCE
# Out:
# [{'symbol': 'BCE',
#   'date': '2019-12-31',
#   'currentRatio': 0.5645903651426818,
#   'quickRatio': 0.014421601718318503,
#   'cashRatio': 0.014421601718318503,
#   'daysOfSalesOutstanding': 0,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.6440661058091977,
#   'debtEquityRatio': 1.8381892379235076,
#   'longTermDebtToCapitalization': 0.515417691830118,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 2.8540381512764545,
#   'receivablesTurnover': None,
#   'payablesTurnover': None,
#   'inventoryTurnover': 0,
#   'fixedAssetTurnover': 0.8671298306556665,
#   'assetTurnover': 0.39843048581784324,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.3320814555166082,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 5.064574806730332,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2018-12-31',
#   'currentRatio': 0.43005469546676556,
#   'quickRatio': 0.11643645128395291,
#   'cashRatio': 0.040975247983684064,
#   'daysOfSalesOutstanding': 0,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.6409523985035844,
#   'debtEquityRatio': 1.8152400835073068,
#   'longTermDebtToCapitalization': 0.4873578595317726,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 2.832098121085595,
#   'receivablesTurnover': None,
#   'payablesTurnover': None,
#   'inventoryTurnover': 0,
#   'fixedAssetTurnover': 0.9453251778804145,
#   'assetTurnover': 0.4186830805521258,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.3250143052070954,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 4.427752864972596,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2018-03-14',
#   'currentRatio': 0.43005469546676556,
#   'quickRatio': 0.040975247983684064,
#   'cashRatio': 0.040975247983684064,
#   'daysOfSalesOutstanding': 0,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.6409523985035844,
#   'debtEquityRatio': 1.8152400835073068,
#   'longTermDebtToCapitalization': 0.4873578595317726,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 2.832098121085595,
#   'receivablesTurnover': None,
#   'payablesTurnover': None,
#   'inventoryTurnover': 0,
#   'fixedAssetTurnover': 0.9453251778804145,
#   'assetTurnover': 0.4186830805521258,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.32386988863946475,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 4.616363636363636,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2017-12-31',
#   'currentRatio': 0.526928811032429,
#   'quickRatio': 0.349795005590756,
#   'cashRatio': 0.05823704808051179,
#   'daysOfSalesOutstanding': 50.1860965856649,
#   'daysOfInventoryOutstanding': 10.29313543599367,
#   'operatingCycle': 60.47923202165857,
#   'daysOfPayablesOutstanding': 104.96289424860652,
#   'cashConversionCycle': -54.77679766294162,
#   'grossProfitMargin': 0.40787450015379717,
#   'operatingProfitMargin': 0.23061036164696666,
#   'pretaxProfitMargin': 0.17853847167904624,
#   'netProfitMargin': 0.13156391439996618,
#   'effectiveTaxRate': 0.2631060792517869,
#   'returnOnAssets': 0.05365399089638429,
#   'returnOnEquity': 0.14747315535415365,
#   'returnOnCapitalEmployed': 0.11133791879298985,
#   'netIncomePerEBT': 0.736893920748213,
#   'ebtPerEbit': 0.8096851335193346,
#   'ebitPerRevenue': 0.220503581315641,
#   'debtRatio': 0.630389591770905,
#   'debtEquityRatio': 1.7326864348340036,
#   'longTermDebtToCapitalization': 0.47290806656800904,
#   'totalDebtToCapitalization': 14308719560.212803,
#   'interestCoverage': 5.254450261780221,
#   'cashFlowToDebtRatio': 0.3145385371692399,
#   'companyEquityMultiplier': 2.7485961974189657,
#   'receivablesTurnover': 7.272930648769727,
#   'payablesTurnover': 3.4774193548387764,
#   'inventoryTurnover': 35.46052631578571,
#   'fixedAssetTurnover': 0.9470639643763816,
#   'assetTurnover': 0.4078169241245842,
#   'operatingCashFlowPerShare': 8.45061041775046,
#   'freeCashFlowPerShare': 3.817590245800774,
#   'cashPerShare': 0.7178080335817403,
#   'payoutRatio': 0.8390113560454163,
#   'operatingCashFlowSalesRatio': 0.32332908555609424,
#   'freeCashFlowOperatingCashFlowRatio': 0.4517531938026569,
#   'cashFlowCoverageRatios': 0.3145385371692399,
#   'shortTermCoverageRatios': 1.4210119737350402,
#   'capitalExpenditureCoverageRatio': -1.8239960337134709,
#   'dividendPaidAndCapexCoverageRatio': -4.834428383705863,
#   'dividendPayoutRatio': 0.8390113560454163,
#   'priceBookValueRatio': 2.075765267894659,
#   'priceToBookRatio': 2.075765267894659,
#   'priceToSalesRatio': 1.851834005747568,
#   'priceEarningsRatio': 14.075546582764522,
#   'priceToFreeCashFlowsRatio': 12.67815477400657,
#   'priceToOperatingCashFlowsRatio': 5.727396910681869,
#   'priceCashFlowRatio': 5.727396910681869,
#   'priceEarningsToGrowthRatio': 4.093409330652356,
#   'priceSalesRatio': 1.851834005747568,
#   'dividendYield': 0.05960772827627057,
#   'enterpriseValueMultiple': 7.324552749807904,
#   'priceFairValue': 2.075765267894659},
#  {'symbol': 'BCE',
#   'date': '2017-03-08',
#   'currentRatio': 0.48031262366442423,
#   'quickRatio': 0.05965571824297586,
#   'cashRatio': 0.05965571824297586,
#   'daysOfSalesOutstanding': 0,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.6436896303983396,
#   'debtEquityRatio': 1.8388825541619156,
#   'longTermDebtToCapitalization': 0.48581144465290804,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 2.8567844925883694,
#   'receivablesTurnover': None,
#   'payablesTurnover': None,
#   'inventoryTurnover': 0,
#   'fixedAssetTurnover': 0.9719412870312361,
#   'assetTurnover': 0.4334437614752135,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.3058612274966619,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 4.5521664766248575,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2016-12-31',
#   'currentRatio': 0.5698158051099195,
#   'quickRatio': 0.3803723509605834,
#   'cashRatio': 0.08447217270746381,
#   'daysOfSalesOutstanding': 50.215019107694175,
#   'daysOfInventoryOutstanding': 11.375377001005651,
#   'operatingCycle': 61.59039610869983,
#   'daysOfPayablesOutstanding': 103.6203696543183,
#   'cashConversionCycle': -53.40535054662412,
#   'grossProfitMargin': 0.4046226806022401,
#   'operatingProfitMargin': 0.23688935954694104,
#   'pretaxProfitMargin': 0.1906625535245648,
#   'netProfitMargin': 0.1395552281412571,
#   'effectiveTaxRate': 0.26805119536345184,
#   'returnOnAssets': 0.058800706151666576,
#   'returnOnEquity': 0.1629394688743123,
#   'returnOnCapitalEmployed': 0.12132982701633432,
#   'netIncomePerEBT': 0.7319488046365481,
#   'ebtPerEbit': 0.8234241399880666,
#   'ebitPerRevenue': 0.23154841383120972,
#   'debtRatio': 0.6330339301996251,
#   'debtEquityRatio': 1.754166218686167,
#   'longTermDebtToCapitalization': 0.4711434582361965,
#   'totalDebtToCapitalization': 12330357142.979088,
#   'interestCoverage': 5.663288288288201,
#   'cashFlowToDebtRatio': 0.309567081411062,
#   'companyEquityMultiplier': 2.7710461240726807,
#   'receivablesTurnover': 7.2687416331994,
#   'payablesTurnover': 3.5224734404794598,
#   'inventoryTurnover': 32.086848635234844,
#   'fixedAssetTurnover': 0.972158811154375,
#   'assetTurnover': 0.4213436281451871,
#   'operatingCashFlowPerShare': 7.674319682015596,
#   'freeCashFlowPerShare': 3.3178753765993276,
#   'cashPerShare': 0.9854274708353382,
#   'payoutRatio': 0.7604750907291604,
#   'operatingCashFlowSalesRatio': 0.30586122749666056,
#   'freeCashFlowOperatingCashFlowRatio': 0.4323347884991827,
#   'cashFlowCoverageRatios': 0.309567081411062,
#   'shortTermCoverageRatios': 1.3593206466134604,
#   'capitalExpenditureCoverageRatio': -1.7616016971625266,
#   'dividendPaidAndCapexCoverageRatio': -4.5313778990450295,
#   'dividendPayoutRatio': 0.7604750907291603,
#   'priceBookValueRatio': 1.9930252484699402,
#   'priceToBookRatio': 1.9930252484699402,
#   'priceToSalesRatio': 1.7069964396168282,
#   'priceEarningsRatio': 12.231691082823605,
#   'priceToFreeCashFlowsRatio': 12.908863395556109,
#   'priceToOperatingCashFlowsRatio': 5.580950725882592,
#   'priceCashFlowRatio': 5.580950725882592,
#   'priceEarningsToGrowthRatio': 3.3495634531910117,
#   'priceSalesRatio': 1.7069964396168282,
#   'dividendYield': 0.06217252263647012,
#   'enterpriseValueMultiple': 6.7565017772095555,
#   'priceFairValue': 1.9930252484699402},
#  {'symbol': 'BCE',
#   'date': '2016-03-09',
#   'currentRatio': 0.4811849479583667,
#   'quickRatio': 0.010008006405124099,
#   'cashRatio': 0.010008006405124099,
#   'daysOfSalesOutstanding': 0,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.6389265101160586,
#   'debtEquityRatio': 1.8013276155789226,
#   'longTermDebtToCapitalization': 0.4748094900194366,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 2.8193032955413266,
#   'receivablesTurnover': None,
#   'payablesTurnover': None,
#   'inventoryTurnover': 0,
#   'fixedAssetTurnover': 0.9946370781322238,
#   'assetTurnover': 0.4482737065822099,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.2916240587524403,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 4.470760233918129,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2015-12-31',
#   'currentRatio': 0.48118494795836525,
#   'quickRatio': 0.36248999199359677,
#   'cashRatio': 0.06134907926341539,
#   'daysOfSalesOutstanding': 51.049781537603266,
#   'daysOfInventoryOutstanding': 11.713337961892009,
#   'operatingCycle': 62.763119499495275,
#   'daysOfPayablesOutstanding': 120.70932654478061,
#   'cashConversionCycle': -69.65954500717734,
#   'grossProfitMargin': 0.39746211769080786,
#   'operatingProfitMargin': 0.21776517616435803,
#   'pretaxProfitMargin': 0.16742586222924508,
#   'netProfitMargin': 0.12447708468904126,
#   'effectiveTaxRate': 0.2565241532481816,
#   'returnOnAssets': 0.055799804138103946,
#   'returnOnEquity': 0.15731657169711652,
#   'returnOnCapitalEmployed': 0.11870740243677973,
#   'netIncomePerEBT': 0.7434758467518183,
#   'ebtPerEbit': 0.7984925737086925,
#   'ebitPerRevenue': 0.20967741935484258,
#   'debtRatio': 0.6389265101160586,
#   'debtEquityRatio': 1.8013276155789175,
#   'longTermDebtToCapitalization': 0.47480949001943507,
#   'totalDebtToCapitalization': 11127982646.552004,
#   'interestCoverage': 4.962596259626238,
#   'cashFlowToDebtRatio': 0.30929258072467597,
#   'companyEquityMultiplier': 2.819303295541318,
#   'receivablesTurnover': 7.149883682286495,
#   'payablesTurnover': 3.023792862141375,
#   'inventoryTurnover': 31.161057692306436,
#   'fixedAssetTurnover': 0.9946370781322221,
#   'assetTurnover': 0.44827370658220805,
#   'operatingCashFlowPerShare': 7.466111366323208,
#   'freeCashFlowPerShare': 3.1511416796340894,
#   'cashPerShare': 0.7294750187370845,
#   'payoutRatio': 0.8099327856609135,
#   'operatingCashFlowSalesRatio': 0.2916240587524425,
#   'freeCashFlowOperatingCashFlowRatio': 0.4220592923175098,
#   'cashFlowCoverageRatios': 0.30929258072467597,
#   'shortTermCoverageRatios': 1.2817160367722333,
#   'capitalExpenditureCoverageRatio': -1.7302813017099001,
#   'dividendPaidAndCapexCoverageRatio': -4.3061084420041,
#   'dividendPayoutRatio': 0.8099327856609136,
#   'priceBookValueRatio': 2.131555227782517,
#   'priceToBookRatio': 2.131555227782517,
#   'priceToSalesRatio': 1.6865977801683578,
#   'priceEarningsRatio': 13.549464018872888,
#   'priceToFreeCashFlowsRatio': 13.70297003117107,
#   'priceToOperatingCashFlowsRatio': 5.783465834004108,
#   'priceCashFlowRatio': 5.783465834004108,
#   'priceEarningsToGrowthRatio': 3.5004718880302312,
#   'priceSalesRatio': 1.6865977801683578,
#   'dividendYield': 0.05977600180588456,
#   'enterpriseValueMultiple': 7.055537087699145,
#   'priceFairValue': 2.131555227782517},
#  {'symbol': 'BCE',
#   'date': '2015-03-11',
#   'currentRatio': 0.5003850808669821,
#   'quickRatio': 0.015623280888986688,
#   'cashRatio': 0.015623280888986688,
#   'daysOfSalesOutstanding': 0,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.6708426031924315,
#   'debtEquityRatio': 2.078014184397163,
#   'longTermDebtToCapitalization': 0.5225072681383981,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 3.0976180917971363,
#   'receivablesTurnover': None,
#   'payablesTurnover': None,
#   'inventoryTurnover': 0,
#   'fixedAssetTurnover': 0.9866366577577719,
#   'assetTurnover': 0.45450029159556776,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.29659728162722176,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 4.696697566628042,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2014-12-31',
#   'currentRatio': 0.5003850808669794,
#   'quickRatio': 0.3999339861370966,
#   'cashRatio': 0.06227307734624544,
#   'daysOfSalesOutstanding': 53.23567151411503,
#   'daysOfInventoryOutstanding': 9.541172776512404,
#   'operatingCycle': 62.77684429062744,
#   'daysOfPayablesOutstanding': 126.01224585917439,
#   'cashConversionCycle': -72.77657434505934,
#   'grossProfitMargin': 0.39459176884326236,
#   'operatingProfitMargin': 0.22027373823781232,
#   'pretaxProfitMargin': 0.16295979469631972,
#   'netProfitMargin': 0.11880999904952036,
#   'effectiveTaxRate': 0.27092446777485074,
#   'returnOnAssets': 0.05399917921247621,
#   'returnOnEquity': 0.16726883447076182,
#   'returnOnCapitalEmployed': 0.11712534938722932,
#   'netIncomePerEBT': 0.7290755322251493,
#   'ebtPerEbit': 0.7868288205598756,
#   'ebitPerRevenue': 0.20710959034312462,
#   'debtRatio': 0.6708426031924318,
#   'debtEquityRatio': 2.0780141843971602,
#   'longTermDebtToCapitalization': 0.5225072681383973,
#   'totalDebtToCapitalization': 14074870912.327108,
#   'interestCoverage': 4.6910656620024245,
#   'cashFlowToDebtRatio': 0.3105284107871424,
#   'companyEquityMultiplier': 3.0976180917971305,
#   'receivablesTurnover': 6.856304985337191,
#   'payablesTurnover': 2.8965438835834063,
#   'inventoryTurnover': 38.25525525525793,
#   'fixedAssetTurnover': 0.9866366577577751,
#   'assetTurnover': 0.45450029159556843,
#   'operatingCashFlowPerShare': 8.043639485568612,
#   'freeCashFlowPerShare': 3.2530277297828936,
#   'cashPerShare': 0.7294824465361353,
#   'payoutRatio': 0.757200000000001,
#   'operatingCashFlowSalesRatio': 0.2965972816272205,
#   'freeCashFlowOperatingCashFlowRatio': 0.40442236821022,
#   'cashFlowCoverageRatios': 0.3105284107871424,
#   'shortTermCoverageRatios': 1.6673791076676383,
#   'capitalExpenditureCoverageRatio': -1.6790422383642647,
#   'dividendPaidAndCapexCoverageRatio': -3.421600877192981,
#   'dividendPayoutRatio': 0.7572000000000011,
#   'priceBookValueRatio': 2.4373180452427246,
#   'priceToBookRatio': 2.4373180452427246,
#   'priceToSalesRatio': 1.7312116483318019,
#   'priceEarningsRatio': 14.571262201679067,
#   'priceToFreeCashFlowsRatio': 14.432708202931131,
#   'priceToOperatingCashFlowsRatio': 5.836910031116476,
#   'priceCashFlowRatio': 5.836910031116476,
#   'priceEarningsToGrowthRatio': 4.136844894998044,
#   'priceSalesRatio': 1.7312116483318019,
#   'dividendYield': 0.051965299197810594,
#   'enterpriseValueMultiple': 7.165192766222504,
#   'priceFairValue': 2.4373180452427246},
#  {'symbol': 'BCE',
#   'date': '2014-03-12',
#   'currentRatio': 0.6425855513307985,
#   'quickRatio': 0.02788339670468948,
#   'cashRatio': 0.02788339670468948,
#   'daysOfSalesOutstanding': 0,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.6419442975497973,
#   'debtEquityRatio': 1.9408433815202184,
#   'longTermDebtToCapitalization': 0.5212107680530748,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 3.0233828525747786,
#   'receivablesTurnover': None,
#   'payablesTurnover': None,
#   'inventoryTurnover': 0,
#   'fixedAssetTurnover': 0.9834643012100468,
#   'assetTurnover': 0.44949762030671603,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.31745098039215686,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 4.7695266272189345,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2013-12-31',
#   'currentRatio': 0.6425855513308023,
#   'quickRatio': 0.4281368821292784,
#   'cashRatio': 0.04245880861851104,
#   'daysOfSalesOutstanding': 54.44583333333253,
#   'daysOfInventoryOutstanding': 11.35529201526972,
#   'operatingCycle': 65.80112534860226,
#   'daysOfPayablesOutstanding': 128.64389570303018,
#   'cashConversionCycle': -74.19806236969765,
#   'grossProfitMargin': 0.3965196078431389,
#   'operatingProfitMargin': 0.21093137254901786,
#   'pretaxProfitMargin': 0.14382352941176543,
#   'netProfitMargin': 0.1032352941176481,
#   'effectiveTaxRate': 0.28220858895705164,
#   'returnOnAssets': 0.046404019037546776,
#   'returnOnEquity': 0.1402971154486728,
#   'returnOnCapitalEmployed': 0.1030831599722627,
#   'netIncomePerEBT': 0.7177914110429484,
#   'ebtPerEbit': 0.7591203104786558,
#   'ebitPerRevenue': 0.18946078431372615,
#   'debtRatio': 0.6419442975497962,
#   'debtEquityRatio': 1.9408433815202195,
#   'longTermDebtToCapitalization': 0.5212107680530748,
#   'totalDebtToCapitalization': 15358082706.842688,
#   'interestCoverage': 4.151450053705714,
#   'cashFlowToDebtRatio': 0.34242808798646296,
#   'companyEquityMultiplier': 3.023382852574785,
#   'receivablesTurnover': 6.703910614525239,
#   'payablesTurnover': 2.837289698087109,
#   'inventoryTurnover': 32.1436031331626,
#   'fixedAssetTurnover': 0.9834643012100484,
#   'assetTurnover': 0.44949762030671636,
#   'operatingCashFlowPerShare': 8.352016122331454,
#   'freeCashFlowPerShare': 3.7465421302304946,
#   'cashPerShare': 0.4320453058958452,
#   'payoutRatio': 0.8523266856600241,
#   'operatingCashFlowSalesRatio': 0.3174509803921546,
#   'freeCashFlowOperatingCashFlowRatio': 0.4485793699814665,
#   'cashFlowCoverageRatios': 0.34242808798646296,
#   'shortTermCoverageRatios': 2.5188642551536713,
#   'capitalExpenditureCoverageRatio': -1.8134976197143542,
#   'dividendPaidAndCapexCoverageRatio': -3.6463963963964354,
#   'dividendPayoutRatio': 0.852326685660024,
#   'priceBookValueRatio': 2.2712364886183773,
#   'priceToBookRatio': 2.2712364886183773,
#   'priceToSalesRatio': 1.671251516208351,
#   'priceEarningsRatio': 16.188761125664776,
#   'priceToFreeCashFlowsRatio': 11.736155225697376,
#   'priceToOperatingCashFlowsRatio': 5.264597117148025,
#   'priceCashFlowRatio': 5.264597117148025,
#   'priceEarningsToGrowthRatio': 5.01607603035065,
#   'priceSalesRatio': 1.671251516208351,
#   'dividendYield': 0.05264928421908654,
#   'enterpriseValueMultiple': 7.269914552194646,
#   'priceFairValue': 2.2712364886183773},
#  {'symbol': 'BCE',
#   'date': '2013-03-13',
#   'currentRatio': None,
#   'quickRatio': None,
#   'cashRatio': None,
#   'daysOfSalesOutstanding': 0,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0.19414267834793492,
#   'pretaxProfitMargin': 0.19414267834793492,
#   'netProfitMargin': 0.19414267834793492,
#   'effectiveTaxRate': 0,
#   'returnOnAssets': None,
#   'returnOnEquity': None,
#   'returnOnCapitalEmployed': None,
#   'netIncomePerEBT': 1,
#   'ebtPerEbit': 1,
#   'ebitPerRevenue': 0.19414267834793492,
#   'debtRatio': None,
#   'debtEquityRatio': None,
#   'longTermDebtToCapitalization': None,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 4.483236994219653,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': None,
#   'receivablesTurnover': None,
#   'payablesTurnover': None,
#   'inventoryTurnover': None,
#   'fixedAssetTurnover': None,
#   'assetTurnover': None,
#   'operatingCashFlowPerShare': 4.853347087653709,
#   'freeCashFlowPerShare': 4.853347087653709,
#   'cashPerShare': 0,
#   'payoutRatio': 0.4339865910263022,
#   'operatingCashFlowSalesRatio': 0.27794743429286606,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': 0.4339865910263022,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': 2.6464109627244055,
#   'priceEarningsRatio': 13.63126843228984,
#   'priceToFreeCashFlowsRatio': 9.521264225579971,
#   'priceToOperatingCashFlowsRatio': 9.521264225579973,
#   'priceCashFlowRatio': 9.521264225579973,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': 2.6464109627244055,
#   'dividendYield': 0.03183757939930754,
#   'enterpriseValueMultiple': 7.275262727830993,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2012-12-31',
#   'currentRatio': 0.5800474355173487,
#   'quickRatio': 0.4558256744737681,
#   'cashRatio': 0.019122442929144175,
#   'daysOfSalesOutstanding': 53.82370607668497,
#   'daysOfInventoryOutstanding': 11.834574028122477,
#   'operatingCycle': 65.65828010480745,
#   'daysOfPayablesOutstanding': 118.22497932175459,
#   'cashConversionCycle': -64.40127324506962,
#   'grossProfitMargin': 0.3948343177495262,
#   'operatingProfitMargin': 0.21839022925217813,
#   'pretaxProfitMargin': 0.16793472820101962,
#   'netProfitMargin': 0.12989288217038625,
#   'effectiveTaxRate': 0.22652757078986602,
#   'returnOnAssets': 0.06334057458078013,
#   'returnOnEquity': 0.18702702702702614,
#   'returnOnCapitalEmployed': 0.12330888583700937,
#   'netIncomePerEBT': 0.773472429210134,
#   'ebtPerEbit': 0.7950236966824644,
#   'ebitPerRevenue': 0.21123235559114836,
#   'debtRatio': 0.640581903390368,
#   'debtEquityRatio': 1.8914594594594634,
#   'longTermDebtToCapitalization': 0.5001981196642783,
#   'totalDebtToCapitalization': 13969818913.552345,
#   'interestCoverage': 4.878612716763007,
#   'cashFlowToDebtRatio': 0.3470228435900654,
#   'companyEquityMultiplier': 2.952720720720728,
#   'receivablesTurnover': 6.781398506449345,
#   'payablesTurnover': 3.087334014300278,
#   'inventoryTurnover': 30.841836734693718,
#   'fixedAssetTurnover': 0.9985505073224377,
#   'assetTurnover': 0.48763699382459996,
#   'operatingCashFlowPerShare': 7.17008393382782,
#   'freeCashFlowPerShare': 2.6371981375319513,
#   'cashPerShare': 0.16635626393234354,
#   'payoutRatio': 0.6485549132947898,
#   'operatingCashFlowSalesRatio': 0.27830613675042737,
#   'freeCashFlowOperatingCashFlowRatio': 0.36780575539567734,
#   'cashFlowCoverageRatios': 0.3470228435900654,
#   'shortTermCoverageRatios': 2.6029962546816274,
#   'capitalExpenditureCoverageRatio': -1.5817923186344534,
#   'dividendPaidAndCapexCoverageRatio': -3.034934497816624,
#   'dividendPayoutRatio': 0.6485549132947898,
#   'priceBookValueRatio': 2.372440092973014,
#   'priceToBookRatio': 2.372440092973014,
#   'priceToSalesRatio': 1.6476927765542306,
#   'priceEarningsRatio': 12.685012057803746,
#   'priceToFreeCashFlowsRatio': 16.0966289926654,
#   'priceToOperatingCashFlowsRatio': 5.920432785971259,
#   'priceCashFlowRatio': 5.920432785971259,
#   'priceEarningsToGrowthRatio': 4.207573000315538,
#   'priceSalesRatio': 1.6476927765542306,
#   'dividendYield': 0.05112765445861776,
#   'enterpriseValueMultiple': 6.412323474776735,
#   'priceFairValue': 2.372440092973014},
#  {'symbol': 'BCE',
#   'date': '2012-03-14',
#   'currentRatio': None,
#   'quickRatio': None,
#   'cashRatio': None,
#   'daysOfSalesOutstanding': None,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': None,
#   'operatingProfitMargin': None,
#   'pretaxProfitMargin': None,
#   'netProfitMargin': None,
#   'effectiveTaxRate': None,
#   'returnOnAssets': None,
#   'returnOnEquity': None,
#   'returnOnCapitalEmployed': None,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': None,
#   'debtRatio': None,
#   'debtEquityRatio': None,
#   'longTermDebtToCapitalization': None,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': None,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': None,
#   'receivablesTurnover': None,
#   'payablesTurnover': None,
#   'inventoryTurnover': None,
#   'fixedAssetTurnover': None,
#   'assetTurnover': None,
#   'operatingCashFlowPerShare': 4.2570491803278685,
#   'freeCashFlowPerShare': 4.2570491803278685,
#   'cashPerShare': 0,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': None,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 9.318661429451632,
#   'priceToOperatingCashFlowsRatio': 9.318661429451634,
#   'priceCashFlowRatio': 9.318661429451634,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': 0.033500422198988654,
#   'enterpriseValueMultiple': 13.913695952161914,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2011-12-31',
#   'currentRatio': 0.6154300044254297,
#   'quickRatio': 0.48502729016078316,
#   'cashRatio': 0.025815016964149708,
#   'daysOfSalesOutstanding': 58.27794019592694,
#   'daysOfInventoryOutstanding': 13.132372767105414,
#   'operatingCycle': 71.41031296303235,
#   'daysOfPayablesOutstanding': 125.38801820020402,
#   'cashConversionCycle': -67.11007800427709,
#   'grossProfitMargin': 0.3912909678412042,
#   'operatingProfitMargin': 0.20305688054572532,
#   'pretaxProfitMargin': 0.15694722264963695,
#   'netProfitMargin': 0.12001846437913291,
#   'effectiveTaxRate': 0.23529411764706668,
#   'returnOnAssets': 0.05936073059360626,
#   'returnOnEquity': 0.16983597038757212,
#   'returnOnCapitalEmployed': 0.1198799056401466,
#   'netIncomePerEBT': 0.7647058823529334,
#   'ebtPerEbit': 0.782008688985422,
#   'ebitPerRevenue': 0.20069754321177716,
#   'debtRatio': 0.6255961440892951,
#   'debtEquityRatio': 1.7898824212512787,
#   'longTermDebtToCapitalization': 0.48005585116419613,
#   'totalDebtToCapitalization': 12447162426.688124,
#   'interestCoverage': 4.587338804220164,
#   'cashFlowToDebtRatio': 0.32838740136238004,
#   'companyEquityMultiplier': 2.861082885759919,
#   'receivablesTurnover': 6.263090266623904,
#   'payablesTurnover': 2.9109639440764856,
#   'inventoryTurnover': 27.793911007024505,
#   'fixedAssetTurnover': 1.03790258184722,
#   'assetTurnover': 0.4945966514459675,
#   'operatingCashFlowPerShare': 6.4724324645040054,
#   'freeCashFlowPerShare': 2.1441843428312137,
#   'cashPerShare': 0.23263004339453872,
#   'payoutRatio': 0.6495726495726488,
#   'operatingCashFlowSalesRatio': 0.2497307278042773,
#   'freeCashFlowOperatingCashFlowRatio': 0.3312795235161294,
#   'cashFlowCoverageRatios': 0.32838740136238004,
#   'shortTermCoverageRatios': 2.3119658119658433,
#   'capitalExpenditureCoverageRatio': -1.4953931203931359,
#   'dividendPaidAndCapexCoverageRatio': -2.804723502304154,
#   'dividendPayoutRatio': 0.6495726495726488,
#   'priceBookValueRatio': 2.1402875912905124,
#   'priceToBookRatio': 2.1402875912905124,
#   'priceToSalesRatio': 1.5124830708724675,
#   'priceEarningsRatio': 12.602086509744048,
#   'priceToFreeCashFlowsRatio': 18.282010187724683,
#   'priceToOperatingCashFlowsRatio': 6.056455623906455,
#   'priceCashFlowRatio': 6.056455623906455,
#   'priceEarningsToGrowthRatio': 3.9440318682317272,
#   'priceSalesRatio': 1.5124830708724675,
#   'dividendYield': 0.05154484926526994,
#   'enterpriseValueMultiple': 6.152896910064174,
#   'priceFairValue': 2.1402875912905124},
#  {'symbol': 'BCE',
#   'date': '2011-03-15',
#   'currentRatio': 0.5968559837728195,
#   'quickRatio': 0.4325557809330629,
#   'cashRatio': 0.1308316430020284,
#   'daysOfSalesOutstanding': 36.057612485472355,
#   'daysOfInventoryOutstanding': 32.22974338250152,
#   'operatingCycle': 68.28735586797387,
#   'daysOfPayablesOutstanding': 301.4992927864215,
#   'cashConversionCycle': -265.44168030094914,
#   'grossProfitMargin': 0.726105484531518,
#   'operatingProfitMargin': 0.20322098621949194,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.8115088529638184,
#   'debtEquityRatio': 1.4603449470111518,
#   'longTermDebtToCapitalization': 0.42293548644975615,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 1.7995428413105217,
#   'receivablesTurnover': 10.122689075630252,
#   'payablesTurnover': 1.2106164383561644,
#   'inventoryTurnover': 11.324942791762014,
#   'fixedAssetTurnover': 0.9172546829788314,
#   'assetTurnover': 0.6954965357967667,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.26144224915601305,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 1.4082423894313614,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2010-12-31',
#   'currentRatio': 0.6693989071038237,
#   'quickRatio': 0.525740580960592,
#   'cashRatio': 0.11087144089731922,
#   'daysOfSalesOutstanding': 58.27798992750034,
#   'daysOfInventoryOutstanding': 14.45378537302403,
#   'operatingCycle': 72.73177530052438,
#   'daysOfPayablesOutstanding': 129.04446894523934,
#   'cashConversionCycle': -70.766479017739,
#   'grossProfitMargin': 0.39764237091150373,
#   'operatingProfitMargin': 0.21019425535447642,
#   'pretaxProfitMargin': 0.15645580829044345,
#   'netProfitMargin': 0.12147877580386125,
#   'effectiveTaxRate': 0.22355854262467237,
#   'returnOnAssets': 0.06115398545677343,
#   'returnOnEquity': 0.21617096710655706,
#   'returnOnCapitalEmployed': 0.12135872006634554,
#   'netIncomePerEBT': 0.7764414573752922,
#   'ebtPerEbit': 0.8049544419134528,
#   'ebitPerRevenue': 0.19436604128617913,
#   'debtRatio': 0.7167135653191428,
#   'debtEquityRatio': 2.533484341146359,
#   'longTermDebtToCapitalization': 0.5102965999517726,
#   'totalDebtToCapitalization': 10612838515.656878,
#   'interestCoverage': 5.127007299269675,
#   'cashFlowToDebtRatio': 0.33206600258535623,
#   'companyEquityMultiplier': 3.534863108134744,
#   'receivablesTurnover': 6.263084922010377,
#   'payablesTurnover': 2.828482328482359,
#   'inventoryTurnover': 25.2529002320196,
#   'fixedAssetTurnover': 1.0165400843881867,
#   'assetTurnover': 0.5034129217396149,
#   'operatingCashFlowPerShare': 5.69227242370098,
#   'freeCashFlowPerShare': 1.7844563654789325,
#   'cashPerShare': 1.0049787127715197,
#   'payoutRatio': 0.6004555808656213,
#   'operatingCashFlowSalesRatio': 0.2416846532735628,
#   'freeCashFlowOperatingCashFlowRatio': 0.31348752003663266,
#   'cashFlowCoverageRatios': 0.33206600258535623,
#   'shortTermCoverageRatios': 1.699221789883269,
#   'capitalExpenditureCoverageRatio': -1.456637758505658,
#   'dividendPaidAndCapexCoverageRatio': -2.5994047619047507,
#   'dividendPayoutRatio': 0.6004555808656212,
#   'priceBookValueRatio': 2.6179635478482832,
#   'priceToBookRatio': 2.6179635478482832,
#   'priceToSalesRatio': 1.4711827917898792,
#   'priceEarningsRatio': 12.11061588375932,
#   'priceToFreeCashFlowsRatio': 19.41767849879604,
#   'priceToOperatingCashFlowsRatio': 6.087199877456215,
#   'priceCashFlowRatio': 6.087199877456215,
#   'priceEarningsToGrowthRatio': 3.9622802923456177,
#   'priceSalesRatio': 1.4711827917898792,
#   'dividendYield': 0.0495809285530102,
#   'enterpriseValueMultiple': 5.870544201424051,
#   'priceFairValue': 2.6179635478482832},
#  {'symbol': 'BCE',
#   'date': '2010-03-17',
#   'currentRatio': 0.686167989970748,
#   'quickRatio': 0.47889678228165483,
#   'cashRatio': 0.1435436690346845,
#   'daysOfSalesOutstanding': 33.032139836481534,
#   'daysOfInventoryOutstanding': 36.13701657458564,
#   'operatingCycle': 69.16915641106718,
#   'daysOfPayablesOutstanding': 299.74364640883977,
#   'cashConversionCycle': -266.71150657235825,
#   'grossProfitMargin': 0.7448548068790527,
#   'operatingProfitMargin': 0.1799266986185509,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 1.4756641458212139,
#   'debtEquityRatio': 2.678822866798085,
#   'longTermDebtToCapitalization': 0.42031587968820144,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 1.8153337088144186,
#   'receivablesTurnover': 11.049844236760125,
#   'payablesTurnover': 1.2177072120559742,
#   'inventoryTurnover': 10.100446428571429,
#   'fixedAssetTurnover': 0.9122473123810504,
#   'assetTurnover': 0.6878029862323056,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.27538765153650974,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 1.4647973178908869,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2009-12-31',
#   'currentRatio': 0.7426998164525337,
#   'quickRatio': 0.5778408142833287,
#   'cashRatio': 0.1141331553479071,
#   'daysOfSalesOutstanding': 57.19396673244986,
#   'daysOfInventoryOutstanding': 35.65303867402942,
#   'operatingCycle': 92.84700540647927,
#   'daysOfPayablesOutstanding': 292.96795580109915,
#   'cashConversionCycle': -235.77398906864929,
#   'grossProfitMargin': 0.7448548068790555,
#   'operatingProfitMargin': 0.1799266986185526,
#   'pretaxProfitMargin': 0.11874823794756002,
#   'netProfitMargin': 0.09799830842965984,
#   'effectiveTaxRate': 0.17473884140549084,
#   'returnOnAssets': 0.049047551855510456,
#   'returnOnEquity': 0.15965460224141192,
#   'returnOnCapitalEmployed': 0.096087222335438,
#   'netIncomePerEBT': 0.8252611585945091,
#   'ebtPerEbit': 0.7444326617179209,
#   'ebitPerRevenue': 0.1595150831688735,
#   'debtRatio': 0.6921969803866238,
#   'debtEquityRatio': 2.253169208157264,
#   'longTermDebtToCapitalization': 0.48614585791833825,
#   'totalDebtToCapitalization': 9827290076.417965,
#   'interestCoverage': 3.912863070539409,
#   'cashFlowToDebtRatio': 0.40055769703929,
#   'companyEquityMultiplier': 3.2550982913834234,
#   'receivablesTurnover': 6.381792011514945,
#   'payablesTurnover': 1.2458700440528883,
#   'inventoryTurnover': 10.237556561087047,
#   'fixedAssetTurnover': 1.0223669798812483,
#   'assetTurnover': 0.5004938620008453,
#   'operatingCashFlowPerShare': 6.081760392393393,
#   'freeCashFlowPerShare': 2.5278406217360194,
#   'cashPerShare': 0.8517453129396182,
#   'payoutRatio': 0.6910241657076956,
#   'operatingCashFlowSalesRatio': 0.275387651536513,
#   'freeCashFlowOperatingCashFlowRatio': 0.41564291564292005,
#   'cashFlowCoverageRatios': 0.40055769703929,
#   'shortTermCoverageRatios': 2.5786694825766516,
#   'capitalExpenditureCoverageRatio': -1.7112824106517301,
#   'dividendPaidAndCapexCoverageRatio': -2.9546279491832936,
#   'dividendPayoutRatio': 0.6910241657076958,
#   'priceBookValueRatio': 1.9917819094248328,
#   'priceToBookRatio': 1.9917819094248328,
#   'priceToSalesRatio': 1.2225845991541482,
#   'priceEarningsRatio': 12.475568392404261,
#   'priceToFreeCashFlowsRatio': 10.681053135959768,
#   'priceToOperatingCashFlowsRatio': 4.439504067567272,
#   'priceCashFlowRatio': 4.439504067567272,
#   'priceEarningsToGrowthRatio': 4.064639335673134,
#   'priceSalesRatio': 1.2225845991541482,
#   'dividendYield': 0.055390194977282585,
#   'enterpriseValueMultiple': 5.353473849354679,
#   'priceFairValue': 1.9917819094248328},
#  {'symbol': 'BCE',
#   'date': '2009-03-17',
#   'currentRatio': 0.8957764573630962,
#   'quickRatio': 0.7862534125582142,
#   'cashRatio': 0.4912477918740967,
#   'daysOfSalesOutstanding': 37.88591931291671,
#   'daysOfInventoryOutstanding': 22.420957542908763,
#   'operatingCycle': 60.30687685582548,
#   'daysOfPayablesOutstanding': 291.6373080397471,
#   'cashConversionCycle': -253.75138872683038,
#   'grossProfitMargin': 0.7498022375409651,
#   'operatingProfitMargin': 0.16182619505028817,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.8244641680555017,
#   'debtEquityRatio': 1.4628980125163331,
#   'longTermDebtToCapitalization': 0.40986201298701297,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 1.77436214840795,
#   'receivablesTurnover': 9.63418617310833,
#   'payablesTurnover': 1.2515545505935557,
#   'inventoryTurnover': 16.279411764705884,
#   'fixedAssetTurnover': 0.9119389910856908,
#   'assetTurnover': 0.6859424053331267,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.3340490450898407,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 1.1478884721995761,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2007-03-14',
#   'currentRatio': 0.7834963845172267,
#   'quickRatio': 0.5208421948107188,
#   'cashRatio': 0.12356444066354742,
#   'daysOfSalesOutstanding': 38.49263252978039,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0.18811042736972844,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.579321914657575,
#   'debtEquityRatio': 1.8303838591091732,
#   'longTermDebtToCapitalization': 0.5036071974197929,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 3.159528084124134,
#   'receivablesTurnover': 9.482334047109207,
#   'payablesTurnover': 0,
#   'inventoryTurnover': None,
#   'fixedAssetTurnover': None,
#   'assetTurnover': 0.47928673864220583,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.30423982385818327,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 1.7467884228447608,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2005-12-31',
#   'currentRatio': 0.6542572141075882,
#   'quickRatio': 0.37923049519059493,
#   'cashRatio': 0.06465977912361952,
#   'daysOfSalesOutstanding': 33.73933525255169,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0.21188170635959172,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.5663549101649028,
#   'debtEquityRatio': 1.763159911117922,
#   'longTermDebtToCapitalization': 0.48148589590782676,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 3.1131714044900773,
#   'receivablesTurnover': 10.818233295583239,
#   'payablesTurnover': 0,
#   'inventoryTurnover': None,
#   'fixedAssetTurnover': None,
#   'assetTurnover': 0.47021904996308145,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.2909709500130856,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 1.6414409382853952,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2005-03-11',
#   'currentRatio': 0.6799853372434017,
#   'quickRatio': 0.45802785923753664,
#   'cashRatio': 0.06964809384164222,
#   'daysOfSalesOutstanding': 40.29776481008701,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0.1550565310269369,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.5670745727205375,
#   'debtEquityRatio': 1.7955832389580975,
#   'longTermDebtToCapitalization': 0.48856067187952507,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 3.166397023135415,
#   'receivablesTurnover': 9.057574327512977,
#   'payablesTurnover': 0,
#   'inventoryTurnover': None,
#   'fixedAssetTurnover': None,
#   'assetTurnover': 0.4903303272615793,
#   'operatingCashFlowPerShare': None,
#   'freeCashFlowPerShare': None,
#   'cashPerShare': None,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0.2875527536080863,
#   'freeCashFlowOperatingCashFlowRatio': 1,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': None,
#   'priceToBookRatio': None,
#   'priceToSalesRatio': None,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': 0,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': None,
#   'dividendYield': None,
#   'enterpriseValueMultiple': 1.87853385930309,
#   'priceFairValue': None},
#  {'symbol': 'BCE',
#   'date': '2004-04-14',
#   'currentRatio': 0.6814462416745957,
#   'quickRatio': 0.5311132254995242,
#   'cashRatio': 0.13587059942911514,
#   'daysOfSalesOutstanding': 39.783007976490346,
#   'daysOfInventoryOutstanding': None,
#   'operatingCycle': None,
#   'daysOfPayablesOutstanding': None,
#   'cashConversionCycle': None,
#   'grossProfitMargin': 1,
#   'operatingProfitMargin': 0.21263643996641476,
#   'pretaxProfitMargin': 0,
#   'netProfitMargin': 0,
#   'effectiveTaxRate': None,
#   'returnOnAssets': 0,
#   'returnOnEquity': 0,
#   'returnOnCapitalEmployed': 0,
#   'netIncomePerEBT': None,
#   'ebtPerEbit': None,
#   'ebitPerRevenue': 0,
#   'debtRatio': 0.5682031984948259,
#   'debtEquityRatio': 1.8764063811922753,
#   'longTermDebtToCapitalization': 0.5099370448092828,
#   'totalDebtToCapitalization': None,
#   'interestCoverage': 0,
#   'cashFlowToDebtRatio': None,
#   'companyEquityMultiplier': 3.302350965575147,
#   'receivablesTurnover': 9.174771304766491,
#   'payablesTurnover': 0,
#   'inventoryTurnover': None,
#   'fixedAssetTurnover': None,
#   'assetTurnover': 0.48450331799344026,
#   'operatingCashFlowPerShare': 0,
#   'freeCashFlowPerShare': 0,
#   'cashPerShare': -0.014788732394366197,
#   'payoutRatio': None,
#   'operatingCashFlowSalesRatio': 0,
#   'freeCashFlowOperatingCashFlowRatio': None,
#   'cashFlowCoverageRatios': None,
#   'shortTermCoverageRatios': None,
#   'capitalExpenditureCoverageRatio': None,
#   'dividendPaidAndCapexCoverageRatio': None,
#   'dividendPayoutRatio': None,
#   'priceBookValueRatio': -79.61538203190597,
#   'priceToBookRatio': -79.61538203190597,
#   'priceToSalesRatio': -49.759613769941225,
#   'priceEarningsRatio': None,
#   'priceToFreeCashFlowsRatio': None,
#   'priceToOperatingCashFlowsRatio': None,
#   'priceCashFlowRatio': None,
#   'priceEarningsToGrowthRatio': None,
#   'priceSalesRatio': -49.759613769941225,
#   'dividendYield': -0.0011495232326027569,
#   'enterpriseValueMultiple': -130.09309626336992,
#   'priceFairValue': -79.61538203190597}]

# %%
# ETR =pd.DataFrame.from_dict(ETR)
BCE =pd.DataFrame.from_dict(BCE)

# %%
# ABG
# BCE

frames = [ABG, BCE]

result = pd.concat(frames)
result
# Out:
#    symbol        date  currentRatio  quickRatio  cashRatio  \
# 0     ABG  2019-12-31      1.285164    0.121973   0.002807
# 1     ABG  2018-12-31      1.191591    0.278677   0.006368
# 2     ABG  2017-12-31      1.230486    0.337176   0.004442
# 3     ABG  2016-12-31      1.205901    0.308173   0.003077
# 4     ABG  2015-12-31      1.332606    0.334789   0.002778
# 5     ABG  2014-12-31      1.226299    0.105561   0.002786
# 6     ABG  2013-12-31      1.328938    0.120355   0.006473
# 7     ABG  2012-12-31      1.264940    0.128494   0.007951
# 8     ABG  2011-12-31      1.245482    0.142071   0.017916
# 9     ABG  2010-12-31      1.381102    0.193701   0.033071
# 10    ABG  2009-12-31      1.362876    0.272575   0.140468
# 11    ABG  2008-12-31      1.193208    0.202576   0.106557
# 12    ABG  2007-12-31      1.367979    0.213595   0.061209
# 13    ABG  2006-12-31      1.467631    0.336792   0.146608
# 14    ABG  2005-12-31      1.413915    0.268794   0.068232
# 15    ABG  2004-12-31      1.349254    0.209949   0.033148
# 16    ABG  2003-12-31      1.153065    0.293917   0.140961
# 0     BCE  2019-12-31      0.564590    0.014422   0.014422
# 1     BCE  2018-12-31      0.430055    0.116436   0.040975
# 2     BCE  2018-03-14      0.430055    0.040975   0.040975
# 3     BCE  2017-12-31      0.526929    0.349795   0.058237
# 4     BCE  2017-03-08      0.480313    0.059656   0.059656
# 5     BCE  2016-12-31      0.569816    0.380372   0.084472
# 6     BCE  2016-03-09      0.481185    0.010008   0.010008
# 7     BCE  2015-12-31      0.481185    0.362490   0.061349
# 8     BCE  2015-03-11      0.500385    0.015623   0.015623
# 9     BCE  2014-12-31      0.500385    0.399934   0.062273
# 10    BCE  2014-03-12      0.642586    0.027883   0.027883
# 11    BCE  2013-12-31      0.642586    0.428137   0.042459
# 12    BCE  2013-03-13           NaN         NaN        NaN
# 13    BCE  2012-12-31      0.580047    0.455826   0.019122
# 14    BCE  2012-03-14           NaN         NaN        NaN
# 15    BCE  2011-12-31      0.615430    0.485027   0.025815
# 16    BCE  2011-03-15      0.596856    0.432556   0.130832
# 17    BCE  2010-12-31      0.669399    0.525741   0.110871
# 18    BCE  2010-03-17      0.686168    0.478897   0.143544
# 19    BCE  2009-12-31      0.742700    0.577841   0.114133
# 20    BCE  2009-03-17      0.895776    0.786253   0.491248
# 21    BCE  2007-03-14      0.783496    0.520842   0.123564
# 22    BCE  2005-12-31      0.654257    0.379230   0.064660
# 23    BCE  2005-03-11      0.679985    0.458028   0.069648
# 24    BCE  2004-04-14      0.681446    0.531113   0.135871
#
#     daysOfSalesOutstanding  daysOfInventoryOutstanding  operatingCycle  \
# 0                 6.965591                   59.510213       66.475804
# 1                 6.987373                   67.518107       74.505480
# 2                 7.354836                   55.825279       63.180115
# 3                 7.844833                   59.724360       67.569193
# 4                 6.692470                   60.565898       67.258368
# 5                 6.655930                   65.991225       72.647155
# 6                 6.499653                   62.864114       69.363767
# 7                 7.393918                   61.057730       68.451648
# 8                 6.742348                   53.327755       60.070104
# 9                 9.458841                   60.185580       69.644421
# 10                7.900000                   59.972012       67.872012
# 11                6.479758                   62.944070       69.423828
# 12                8.514165                   58.264897       66.779062
# 13               10.639633                   58.103067       68.742700
# 14               11.014764                   55.095188       66.109952
# 15               10.203766                   61.944261       72.148027
# 16                8.726750                   58.816423       67.543173
# 0                 0.000000                         NaN             NaN
# 1                 0.000000                         NaN             NaN
# 2                 0.000000                         NaN             NaN
# 3                50.186097                   10.293135       60.479232
# 4                 0.000000                         NaN             NaN
# 5                50.215019                   11.375377       61.590396
# 6                 0.000000                         NaN             NaN
# 7                51.049782                   11.713338       62.763119
# 8                 0.000000                         NaN             NaN
# 9                53.235672                    9.541173       62.776844
# 10                0.000000                         NaN             NaN
# 11               54.445833                   11.355292       65.801125
# 12                0.000000                         NaN             NaN
# 13               53.823706                   11.834574       65.658280
# 14                     NaN                         NaN             NaN
# 15               58.277940                   13.132373       71.410313
# 16               36.057612                   32.229743       68.287356
# 17               58.277990                   14.453785       72.731775
# 18               33.032140                   36.137017       69.169156
# 19               57.193967                   35.653039       92.847005
# 20               37.885919                   22.420958       60.306877
# 21               38.492633                         NaN             NaN
# 22               33.739335                         NaN             NaN
# 23               40.297765                         NaN             NaN
# 24               39.783008                         NaN             NaN
#
#     daysOfPayablesOutstanding  cashConversionCycle  ...  priceToSalesRatio  \
# 0                   18.650561           -11.684970  ...       2.633889e-01
# 1                   18.871678           -11.884304  ...       2.053157e-01
# 2                   21.167648           -13.812812  ...       2.390397e-01
# 3                   20.628897           -12.784064  ...       2.236971e-01
# 4                   18.601628           -11.909158  ...       1.879398e-01
# 5                   18.292827           -11.636897  ...       3.781514e-01
# 6                   17.490914           -10.991261  ...       2.744925e-01
# 7                   19.687234           -12.293315  ...       2.298838e-01
# 8                   18.764800           -12.022452  ...       1.731760e-01
# 9                   18.877396            -9.418554  ...       1.497561e-07
# 10                  17.787290            -9.887290  ...       9.705205e-08
# 11                  14.271103            -7.791346  ...       2.402685e-08
# 12                  14.083680            -5.569515  ...       7.180744e-02
# 13                   4.792580             5.847053  ...       1.293923e-01
# 14                   5.622295             5.392469  ...       1.050235e-01
# 15                   4.317310             5.886456  ...       1.037389e-01
# 16                   3.877887             4.848863  ...       1.192729e-01
# 0                         NaN                  NaN  ...                NaN
# 1                         NaN                  NaN  ...                NaN
# 2                         NaN                  NaN  ...                NaN
# 3                  104.962894           -54.776798  ...       1.851834e+00
# 4                         NaN                  NaN  ...                NaN
# 5                  103.620370           -53.405351  ...       1.706996e+00
# 6                         NaN                  NaN  ...                NaN
# 7                  120.709327           -69.659545  ...       1.686598e+00
# 8                         NaN                  NaN  ...                NaN
# 9                  126.012246           -72.776574  ...       1.731212e+00
# 10                        NaN                  NaN  ...                NaN
# 11                 128.643896           -74.198062  ...       1.671252e+00
# 12                        NaN                  NaN  ...       2.646411e+00
# 13                 118.224979           -64.401273  ...       1.647693e+00
# 14                        NaN                  NaN  ...                NaN
# 15                 125.388018           -67.110078  ...       1.512483e+00
# 16                 301.499293          -265.441680  ...                NaN
# 17                 129.044469           -70.766479  ...       1.471183e+00
# 18                 299.743646          -266.711507  ...                NaN
# 19                 292.967956          -235.773989  ...       1.222585e+00
# 20                 291.637308          -253.751389  ...                NaN
# 21                        NaN                  NaN  ...                NaN
# 22                        NaN                  NaN  ...                NaN
# 23                        NaN                  NaN  ...                NaN
# 24                        NaN                  NaN  ...      -4.975961e+01
#
#     priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 0         1.029888e+01               6.499360e+00
# 1         8.401321e+00              -4.673583e+01
# 2         1.109533e+01               6.890000e+00
# 3         8.733553e+00               2.397783e+01
# 4         7.317991e+00               1.479336e+01
# 5         1.988243e+01               8.310408e+01
# 6         1.342246e+01               1.830487e+03
# 7         1.297725e+01              -1.383567e+01
# 8         1.090754e+01              -3.639420e+00
# 9         1.551158e-05               6.549333e-05
# 10        2.724923e-05               3.220364e-06
# 11       -3.435913e-07               2.097921e-07
# 12        6.730964e+00               5.897360e+00
# 13        1.224365e+01               5.784601e+00
# 14        9.526691e+00              -1.438317e+01
# 15        1.098264e+01              -7.611541e+01
# 16        3.751285e+01               5.896984e+00
# 0                  NaN               0.000000e+00
# 1                  NaN               0.000000e+00
# 2                  NaN               0.000000e+00
# 3         1.407555e+01               1.267815e+01
# 4                  NaN               0.000000e+00
# 5         1.223169e+01               1.290886e+01
# 6                  NaN               0.000000e+00
# 7         1.354946e+01               1.370297e+01
# 8                  NaN               0.000000e+00
# 9         1.457126e+01               1.443271e+01
# 10                 NaN               0.000000e+00
# 11        1.618876e+01               1.173616e+01
# 12        1.363127e+01               9.521264e+00
# 13        1.268501e+01               1.609663e+01
# 14                 NaN               9.318661e+00
# 15        1.260209e+01               1.828201e+01
# 16                 NaN               0.000000e+00
# 17        1.211062e+01               1.941768e+01
# 18                 NaN               0.000000e+00
# 19        1.247557e+01               1.068105e+01
# 20                 NaN               0.000000e+00
# 21                 NaN               0.000000e+00
# 22                 NaN               0.000000e+00
# 23                 NaN               0.000000e+00
# 24                 NaN                        NaN
#
#     priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 0                     5.429140e+00        5.429140e+00
# 1                     1.397448e+02        1.397448e+02
# 2                     5.795569e+00        5.795569e+00
# 3                     1.026177e+01        1.026177e+01
# 4                     7.967851e+00        7.967851e+00
# 5                     2.635248e+01        2.635248e+01
# 6                     2.888343e+01        2.888343e+01
# 7                    -5.153285e+01       -5.153285e+01
# 8                    -4.089575e+00       -4.089575e+00
# 9                     6.549333e-05        6.549333e-05
# 10                    3.220364e-06        3.220364e-06
# 11                    2.097921e-07        2.097921e-07
# 12                    5.897360e+00        5.897360e+00
# 13                    5.784601e+00        5.784601e+00
# 14                   -1.438317e+01       -1.438317e+01
# 15                   -5.278689e+01       -5.278689e+01
# 16                    5.896984e+00        5.896984e+00
# 0                              NaN                 NaN
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                     5.727397e+00        5.727397e+00
# 4                              NaN                 NaN
# 5                     5.580951e+00        5.580951e+00
# 6                              NaN                 NaN
# 7                     5.783466e+00        5.783466e+00
# 8                              NaN                 NaN
# 9                     5.836910e+00        5.836910e+00
# 10                             NaN                 NaN
# 11                    5.264597e+00        5.264597e+00
# 12                    9.521264e+00        9.521264e+00
# 13                    5.920433e+00        5.920433e+00
# 14                    9.318661e+00        9.318661e+00
# 15                    6.056456e+00        6.056456e+00
# 16                             NaN                 NaN
# 17                    6.087200e+00        6.087200e+00
# 18                             NaN                 NaN
# 19                    4.439504e+00        4.439504e+00
# 20                             NaN                 NaN
# 21                             NaN                 NaN
# 22                             NaN                 NaN
# 23                             NaN                 NaN
# 24                             NaN                 NaN
#
#     priceEarningsToGrowthRatio  priceSalesRatio  dividendYield  \
# 0                 1.170884e+00     2.633889e-01            NaN
# 1                 1.005158e+00     2.053157e-01            NaN
# 2                 1.373707e+00     2.390397e-01            NaN
# 3                 1.169672e+00     2.236971e-01            NaN
# 4                 1.145614e+00     1.879398e-01            NaN
# 5                 3.538599e+00     3.781514e-01            NaN
# 6                 2.452794e+00     2.744925e-01            NaN
# 7                 2.402336e+00     2.298838e-01            NaN
# 8                 2.064642e+00     1.731760e-01            NaN
# 9                 2.954586e-12     1.497561e-07            NaN
# 10                5.190330e-12     9.705205e-08            NaN
# 11               -6.340078e-14     2.402685e-08  189223.283474
# 12                1.235495e+00     7.180744e-02       0.067652
# 13                2.247371e+00     1.293923e-01       0.017938
# 14                1.853792e+00     1.050235e-01            NaN
# 15                2.124749e+00     1.037389e-01            NaN
# 16                7.289997e+00     1.192729e-01            NaN
# 0                          NaN              NaN            NaN
# 1                          NaN              NaN            NaN
# 2                          NaN              NaN            NaN
# 3                 4.093409e+00     1.851834e+00       0.059608
# 4                          NaN              NaN            NaN
# 5                 3.349563e+00     1.706996e+00       0.062173
# 6                          NaN              NaN            NaN
# 7                 3.500472e+00     1.686598e+00       0.059776
# 8                          NaN              NaN            NaN
# 9                 4.136845e+00     1.731212e+00       0.051965
# 10                         NaN              NaN            NaN
# 11                5.016076e+00     1.671252e+00       0.052649
# 12                         NaN     2.646411e+00       0.031838
# 13                4.207573e+00     1.647693e+00       0.051128
# 14                         NaN              NaN       0.033500
# 15                3.944032e+00     1.512483e+00       0.051545
# 16                         NaN              NaN            NaN
# 17                3.962280e+00     1.471183e+00       0.049581
# 18                         NaN              NaN            NaN
# 19                4.064639e+00     1.222585e+00       0.055390
# 20                         NaN              NaN            NaN
# 21                         NaN              NaN            NaN
# 22                         NaN              NaN            NaN
# 23                         NaN              NaN            NaN
# 24                         NaN    -4.975961e+01      -0.001150
#
#     enterpriseValueMultiple  priceFairValue
# 0                  7.367497    2.938439e+00
# 1                  6.288265    2.982718e+00
# 2                  7.054822    3.915170e+00
# 3                  6.810143    5.220772e+00
# 4                  6.254510    3.937056e+00
# 5                  9.473036    4.987366e+00
# 6                  7.728944    2.984896e+00
# 7                  7.008861    2.648287e+00
# 8                  7.207658    2.267673e+00
# 9                 14.818209    2.053798e-06
# 10                12.818198    1.457778e-06
# 11                18.541671    4.999099e-07
# 12                23.981780    6.999005e-01
# 13                 5.174665    1.215674e+00
# 14                 4.090312    1.062315e+00
# 15                 7.376222    1.145641e+00
# 16                 9.045206    1.313577e+00
# 0                  5.064575             NaN
# 1                  4.427753             NaN
# 2                  4.616364             NaN
# 3                  7.324553    2.075765e+00
# 4                  4.552166             NaN
# 5                  6.756502    1.993025e+00
# 6                  4.470760             NaN
# 7                  7.055537    2.131555e+00
# 8                  4.696698             NaN
# 9                  7.165193    2.437318e+00
# 10                 4.769527             NaN
# 11                 7.269915    2.271236e+00
# 12                 7.275263             NaN
# 13                 6.412323    2.372440e+00
# 14                13.913696             NaN
# 15                 6.152897    2.140288e+00
# 16                 1.408242             NaN
# 17                 5.870544    2.617964e+00
# 18                 1.464797             NaN
# 19                 5.353474    1.991782e+00
# 20                 1.147888             NaN
# 21                 1.746788             NaN
# 22                 1.641441             NaN
# 23                 1.878534             NaN
# 24              -130.093096   -7.961538e+01
#
# [42 rows x 56 columns]

# %%
ABG.currentRatio.plot()
