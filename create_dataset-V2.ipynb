# %%
import pandas as pd
import re

# %% [markdown]
# # Import Datasets

# %%
df_ratings = pd.read_csv('stocks_us/ratings-history (1).csv')
df_ratings = df_ratings.rename(columns={"Obligor Name": "Name"})

# %%
df_ratings_count = df_ratings.groupby('Rating').count().reset_index().sort_values(by=['Rating Agency Name'],ascending=False)

# %%
rating_set = {'A', 'A+', 'A-', 'AA', 'AA-', 'AAA', 
              'B', 'B+', 'B-', 'BB', 'BB+', 'BB-', 'BBB', 'BBB+', 'BBB-',
              'CC', 'CCC', 'CCC+', 'CCC-', 'D'}

# %%
df_ratings = df_ratings[df_ratings['Rating'].isin(rating_set)]

# %%
df_ratings = df_ratings.drop_duplicates(subset = df_ratings.columns)

# %% [markdown]
# #### Import US stocks

# %%
df_is_stocks = pd.read_csv('stocks_us/us_stocks.csv')

# %%
df_is_stocks
# Out:
#      Symbol                              Name             Sector  \
# 0         A        Agilent Technologies, Inc.      Capital Goods
# 1        AA                 Alcoa Corporation   Basic Industries
# 2      AACG             ATA Creativity Global  Consumer Services
# 3       AAL     American Airlines Group, Inc.     Transportation
# 4      AAMC  Altisource Asset Management Corp            Finance
# ...     ...                               ...                ...
# 7017    ZVO                        Zovio Inc.  Consumer Services
# 7018   ZYME                    Zymeworks Inc.        Health Care
# 7019   ZYNE     Zynerba Pharmaceuticals, Inc.        Health Care
# 7020   ZYXI                       Zynex, Inc.        Health Care
# 7021   TRUE                     TrueCar, Inc.         Technology
#
#                                                industry
# 0      Biotechnology: Laboratory Analytical Instruments
# 1                                              Aluminum
# 2                               Other Consumer Services
# 3                         Air Freight/Delivery Services
# 4                                           Real Estate
# ...                                                 ...
# 7017                            Other Consumer Services
# 7018                              Major Pharmaceuticals
# 7019                              Major Pharmaceuticals
# 7020  Biotechnology: Electromedical & Electrotherape...
# 7021    Computer Software: Programming, Data Processing
#
# [7022 rows x 4 columns]

# %% [markdown]
# ### Clean Names

# %%
df_is_stocks['Clean_Name'] = df_is_stocks['Name']

# %%
def clean(company_name):
    
    name = company_name.lower()
    name = re.sub(r'^a-z', '', name)
    name = re.sub(r'inc', '', name)
    name = re.sub(r'ltd', '', name)
    name = re.sub(r'limited', '', name)
    name = re.sub(r'ltd', '', name)
    name = re.sub(r'corporation', '', name)
    name = re.sub(r'holdings', '', name)
    name = re.sub(r'LLC', '', name)   
    name = re.sub(r'\.', '', name)
    name = re.sub(r',', '', name)
    name.strip()
    return name

# %%
df_is_stocks['Clean_Name'] = df_is_stocks['Clean_Name'].apply(clean)

# %%
df_ratings['Clean_Name'] = df_ratings['Name']

# %%
df_ratings['Clean_Name'] = df_ratings['Clean_Name'].apply(clean)

# %%
pd.merge(df_ratings, df_is_stocks ,on='Clean_Name')
# Out:
#                       Rating Agency Name                       Name_x Rating  \
# 0     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# 1     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# 2     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# 3     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# 4     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# ...                                  ...                          ...    ...
# 6671    Morningstar Credit Ratings, LLC.  Discover Financial Services   BBB+
# 6672    Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
# 6673    Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
# 6674    Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
# 6675    Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
#
#      Rating Outlook Rating Action Date Symbol_x Sector_x  \
# 0            Stable          1/25/2012      CXO   Energy
# 1            Stable          5/13/2016      CXO   Energy
# 2            Stable          5/15/2015      CXO   Energy
# 3          Positive          8/19/2016      CXO   Energy
# 4            Stable           2/9/2016      CXO   Energy
# ...             ...                ...      ...      ...
# 6671            NaN          7/19/2010      DFS  Finance
# 6672            NaN           8/4/2014      SYF  Finance
# 6673            NaN           8/4/2014      SYF  Finance
# 6674            NaN           8/4/2014    SYF^A      NaN
# 6675            NaN           8/4/2014    SYF^A      NaN
#
#                       industry_x                   Clean_Name Symbol_y  \
# 0           Oil & Gas Production            concho resources       CXO
# 1           Oil & Gas Production            concho resources       CXO
# 2           Oil & Gas Production            concho resources       CXO
# 3           Oil & Gas Production            concho resources       CXO
# 4           Oil & Gas Production            concho resources       CXO
# ...                          ...                          ...      ...
# 6671  Finance: Consumer Services  discover financial services      DFS
# 6672  Finance: Consumer Services          synchrony financial      SYF
# 6673  Finance: Consumer Services          synchrony financial    SYF^A
# 6674                         NaN          synchrony financial      SYF
# 6675                         NaN          synchrony financial    SYF^A
#
#                            Name_y Sector_y                  industry_y
# 0           Concho Resources Inc.   Energy        Oil & Gas Production
# 1           Concho Resources Inc.   Energy        Oil & Gas Production
# 2           Concho Resources Inc.   Energy        Oil & Gas Production
# 3           Concho Resources Inc.   Energy        Oil & Gas Production
# 4           Concho Resources Inc.   Energy        Oil & Gas Production
# ...                           ...      ...                         ...
# 6671  Discover Financial Services  Finance  Finance: Consumer Services
# 6672          Synchrony Financial  Finance  Finance: Consumer Services
# 6673          Synchrony Financial      NaN                         NaN
# 6674          Synchrony Financial  Finance  Finance: Consumer Services
# 6675          Synchrony Financial      NaN                         NaN
#
# [6676 rows x 13 columns]

# %%
df_ratings = pd.merge(df_ratings, df_is_stocks ,on='Clean_Name')

# %%
df_ratings.tail()
# Out:
#                     Rating Agency Name                       Name_x Rating  \
# 6671  Morningstar Credit Ratings, LLC.  Discover Financial Services   BBB+
# 6672  Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
# 6673  Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
# 6674  Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
# 6675  Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
#
#      Rating Outlook Rating Action Date Symbol_x Sector_x  \
# 6671            NaN          7/19/2010      DFS  Finance
# 6672            NaN           8/4/2014      SYF  Finance
# 6673            NaN           8/4/2014      SYF  Finance
# 6674            NaN           8/4/2014    SYF^A      NaN
# 6675            NaN           8/4/2014    SYF^A      NaN
#
#                       industry_x                   Clean_Name Symbol_y  \
# 6671  Finance: Consumer Services  discover financial services      DFS
# 6672  Finance: Consumer Services          synchrony financial      SYF
# 6673  Finance: Consumer Services          synchrony financial    SYF^A
# 6674                         NaN          synchrony financial      SYF
# 6675                         NaN          synchrony financial    SYF^A
#
#                            Name_y Sector_y                  industry_y
# 6671  Discover Financial Services  Finance  Finance: Consumer Services
# 6672          Synchrony Financial  Finance  Finance: Consumer Services
# 6673          Synchrony Financial      NaN                         NaN
# 6674          Synchrony Financial  Finance  Finance: Consumer Services
# 6675          Synchrony Financial      NaN                         NaN

# %%
df_ratings.groupby('Rating').count()
# Out:
#         Rating Agency Name  Name_x  Rating Outlook  Rating Action Date  \
# Rating
# A                     1551    1551            1473                1551
# A+                     318     318              64                 318
# A-                     721     721             277                 721
# AA                      61      61              49                  61
# AA-                     44      44              36                  44
# AAA                      8       8               7                   8
# B                      187     187             163                 187
# B+                     175     175             145                 175
# B-                      73      73              58                  73
# BB                     387     387             351                 387
# BB+                    448     448             350                 448
# BB-                    230     230             201                 230
# BBB                    900     900             387                 900
# BBB+                  1006    1006             464                1006
# BBB-                   486     486             326                 486
# CC                      10      10               8                  10
# CCC                     29      29              20                  29
# CCC+                    19      19              18                  19
# CCC-                    13      13              13                  13
# D                       10      10               9                  10
#
#         Symbol_x  Sector_x  industry_x  Clean_Name  Symbol_y  Name_y  \
# Rating
# A           1551       798         798        1551      1551    1551
# A+           318       192         192         318       318     318
# A-           721       302         302         721       721     721
# AA            61        29          29          61        61      61
# AA-           44        36          36          44        44      44
# AAA            8         8           8           8         8       8
# B            187       156         156         187       187     187
# B+           175       159         159         175       175     175
# B-            73        61          61          73        73      73
# BB           387       298         298         387       387     387
# BB+          448       330         330         448       448     448
# BB-          230       189         189         230       230     230
# BBB          900       500         500         900       900     900
# BBB+        1006       548         548        1006      1006    1006
# BBB-         486       433         433         486       486     486
# CC            10         8           8          10        10      10
# CCC           29        21          21          29        29      29
# CCC+          19        19          19          19        19      19
# CCC-          13        10          10          13        13      13
# D             10         4           4          10        10      10
#
#         Sector_y  industry_y
# Rating
# A            798         798
# A+           192         192
# A-           302         302
# AA            29          29
# AA-           36          36
# AAA            8           8
# B            156         156
# B+           159         159
# B-            61          61
# BB           298         298
# BB+          330         330
# BB-          189         189
# BBB          500         500
# BBB+         548         548
# BBB-         433         433
# CC             8           8
# CCC           21          21
# CCC+          19          19
# CCC-          10          10
# D              4           4

# %%
df_ratings
# Out:
#                       Rating Agency Name                       Name_x Rating  \
# 0     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# 1     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# 2     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# 3     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# 4     Standard & Poor's Ratings Services        Concho Resources Inc.    BB+
# ...                                  ...                          ...    ...
# 6671    Morningstar Credit Ratings, LLC.  Discover Financial Services   BBB+
# 6672    Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
# 6673    Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
# 6674    Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
# 6675    Morningstar Credit Ratings, LLC.          Synchrony Financial    BBB
#
#      Rating Outlook Rating Action Date Symbol_x Sector_x  \
# 0            Stable          1/25/2012      CXO   Energy
# 1            Stable          5/13/2016      CXO   Energy
# 2            Stable          5/15/2015      CXO   Energy
# 3          Positive          8/19/2016      CXO   Energy
# 4            Stable           2/9/2016      CXO   Energy
# ...             ...                ...      ...      ...
# 6671            NaN          7/19/2010      DFS  Finance
# 6672            NaN           8/4/2014      SYF  Finance
# 6673            NaN           8/4/2014      SYF  Finance
# 6674            NaN           8/4/2014    SYF^A      NaN
# 6675            NaN           8/4/2014    SYF^A      NaN
#
#                       industry_x                   Clean_Name Symbol_y  \
# 0           Oil & Gas Production            concho resources       CXO
# 1           Oil & Gas Production            concho resources       CXO
# 2           Oil & Gas Production            concho resources       CXO
# 3           Oil & Gas Production            concho resources       CXO
# 4           Oil & Gas Production            concho resources       CXO
# ...                          ...                          ...      ...
# 6671  Finance: Consumer Services  discover financial services      DFS
# 6672  Finance: Consumer Services          synchrony financial      SYF
# 6673  Finance: Consumer Services          synchrony financial    SYF^A
# 6674                         NaN          synchrony financial      SYF
# 6675                         NaN          synchrony financial    SYF^A
#
#                            Name_y Sector_y                  industry_y
# 0           Concho Resources Inc.   Energy        Oil & Gas Production
# 1           Concho Resources Inc.   Energy        Oil & Gas Production
# 2           Concho Resources Inc.   Energy        Oil & Gas Production
# 3           Concho Resources Inc.   Energy        Oil & Gas Production
# 4           Concho Resources Inc.   Energy        Oil & Gas Production
# ...                           ...      ...                         ...
# 6671  Discover Financial Services  Finance  Finance: Consumer Services
# 6672          Synchrony Financial  Finance  Finance: Consumer Services
# 6673          Synchrony Financial      NaN                         NaN
# 6674          Synchrony Financial  Finance  Finance: Consumer Services
# 6675          Synchrony Financial      NaN                         NaN
#
# [6676 rows x 13 columns]

# %%
df_ratings.groupby('Rating').count()
# Out:
#         Rating Agency Name  Name_x  Rating Outlook  Rating Action Date  \
# Rating
# A                     1551    1551            1473                1551
# A+                     318     318              64                 318
# A-                     721     721             277                 721
# AA                      61      61              49                  61
# AA-                     44      44              36                  44
# AAA                      8       8               7                   8
# B                      187     187             163                 187
# B+                     175     175             145                 175
# B-                      73      73              58                  73
# BB                     387     387             351                 387
# BB+                    448     448             350                 448
# BB-                    230     230             201                 230
# BBB                    900     900             387                 900
# BBB+                  1006    1006             464                1006
# BBB-                   486     486             326                 486
# CC                      10      10               8                  10
# CCC                     29      29              20                  29
# CCC+                    19      19              18                  19
# CCC-                    13      13              13                  13
# D                       10      10               9                  10
#
#         Symbol_x  Sector_x  industry_x  Clean_Name  Symbol_y  Name_y  \
# Rating
# A           1551       798         798        1551      1551    1551
# A+           318       192         192         318       318     318
# A-           721       302         302         721       721     721
# AA            61        29          29          61        61      61
# AA-           44        36          36          44        44      44
# AAA            8         8           8           8         8       8
# B            187       156         156         187       187     187
# B+           175       159         159         175       175     175
# B-            73        61          61          73        73      73
# BB           387       298         298         387       387     387
# BB+          448       330         330         448       448     448
# BB-          230       189         189         230       230     230
# BBB          900       500         500         900       900     900
# BBB+        1006       548         548        1006      1006    1006
# BBB-         486       433         433         486       486     486
# CC            10         8           8          10        10      10
# CCC           29        21          21          29        29      29
# CCC+          19        19          19          19        19      19
# CCC-          13        10          10          13        13      13
# D             10         4           4          10        10      10
#
#         Sector_y  industry_y
# Rating
# A            798         798
# A+           192         192
# A-           302         302
# AA            29          29
# AA-           36          36
# AAA            8           8
# B            156         156
# B+           159         159
# B-            61          61
# BB           298         298
# BB+          330         330
# BB-          189         189
# BBB          500         500
# BBB+         548         548
# BBB-         433         433
# CC             8           8
# CCC           21          21
# CCC+          19          19
# CCC-          10          10
# D              4           4

# %% [markdown]
# # API Function get Data

# %%
#!/usr/bin/env python

try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import json

def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url)
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://financialmodelingprep.com/api/v3/ratios/BCE?apikey=c283e7eb3ddc10dcc0ed8146046dff97")
BCE = get_jsonparsed_data(url)
