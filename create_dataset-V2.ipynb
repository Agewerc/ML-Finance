# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import re

# %% [markdown]
# #### Import Datasets

# %%
df_ratings = pd.read_csv('stocks_us/ratings-history.csv')
df_is_stocks = pd.read_csv('stocks_us/us_stocks.csv')

# %%
rating_set = {'A', 'A+', 'A-', 'AA', 'AA-', 'AAA', 
              'B', 'B+', 'B-', 'BB', 'BB+', 'BB-', 'BBB', 'BBB+', 'BBB-',
              'CC', 'CCC', 'CCC+', 'CCC-', 'D'}

# %%
df_ratings = df_ratings[df_ratings['Rating'].isin(rating_set)]

# %%
df_ratings = df_ratings.drop_duplicates(subset = df_ratings.columns)

# %%
df_ratings['Rating'] = df_ratings['Rating'].str.replace(r'+', '').str.replace(r'-', '')

# %% [markdown]
# ## Clean Company Names

# %%
df_is_stocks['Clean_Name'] = df_is_stocks['Name']
df_ratings['Clean_Name'] = df_ratings['Name']

# %%
def clean(company_name):
    
    name = company_name.lower()
    name = re.sub(r'^a-z', '', name)
    name = re.sub(r'inc', '', name)
    name = re.sub(r'ltd', '', name)
    name = re.sub(r'limited', '', name)
    name = re.sub(r'ltd', '', name)
    name = re.sub(r'corporation', '', name)
    name = re.sub(r'holdings', '', name)
    name = re.sub(r'LLC', '', name)   
    name = re.sub(r'\.', '', name)
    name = re.sub(r',', '', name)
    name.strip()
    return name

# %%
df_is_stocks['Clean_Name'] = df_is_stocks['Clean_Name'].apply(clean)
df_ratings['Clean_Name'] = df_ratings['Clean_Name'].apply(clean)

# %%
df_ratings = pd.merge(df_ratings, df_is_stocks ,on='Clean_Name')

# %%
df_ratings = df_ratings.rename(columns = {'Name_x': 'Name'}).drop('Name_y', axis = 1)

# %%
df_ratings.groupby('Rating').count()
# Out:
#         Rating Agency Name  Name  Rating Outlook  date  Clean_Name  Symbol  \
# Rating
# A                     1190  1190             866  1190        1190    1190
# AA                     173   173             124   173         173     173
# AAA                     20    20              18    20          20      20
# B                     1105  1105             946  1105        1105    1105
# BB                    1909  1909            1690  1909        1909    1909
# BBB                   2322  2322            1728  2322        2322    2322
# CC                      16    16              11    16          16      16
# CCC                    138   138             118   138         138     138
# D                       13    13               9    13          13      13
#
#         Sector  industry
# Rating
# A          965       965
# AA         151       151
# AAA         20        20
# B         1021      1021
# BB        1694      1694
# BBB       2006      2006
# CC          15        15
# CCC        129       129
# D            9         9

# %% [markdown]
# ## API Function get Data

# %%
#!/usr/bin/env python

try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import json

def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    
    response = urlopen(url)
    data = response.read().decode("utf-8")
    
    return json.loads(data)

# %% [markdown]
# ## Get Financial Data

# %%
Symbol_list = list(set(df_ratings.Symbol))

# %%
company_ratios = pd.DataFrame.from_dict(get_jsonparsed_data("https://financialmodelingprep.com/api/v3/ratios/" + Symbol_list[0] + 
                                                         "?apikey=c283e7eb3ddc10dcc0ed8146046dff97"))

company_ratios = company_ratios[0:0]

# %%
for Symbol in Symbol_list:
    
    if Symbol.isalpha() == True:
    
        ratios = pd.DataFrame.from_dict(get_jsonparsed_data("https://financialmodelingprep.com/api/v3/ratios/" + 
                                                             Symbol + "?apikey=c283e7eb3ddc10dcc0ed8146046dff97"))
    
        frames = [company_ratios, ratios]
    
        company_ratios = pd.concat(frames)

# %%
company_ratios.head()
# Out:
#   Symbol       date currentRatio quickRatio    cashRatio  \
# 0    DNR 2019-12-31     0.495854   0.416899   0.00141664
# 1    DNR 2018-12-31     0.812225   0.705682     0.105704
# 2    DNR 2017-12-31      0.44155   0.319593  0.000126622
# 3    DNR 2016-12-31     0.417826    0.29191   0.00370476
# 4    DNR 2015-12-31     0.924113   0.659681   0.00753857
#
#    daysOfSalesOutstanding daysOfInventoryOutstanding operatingCycle  \
# 0               39.910329                          0        39.9103
# 1               31.156244                          0        31.1562
# 2               47.276130                        NaN            NaN
# 3               46.742340                        NaN            NaN
# 4               29.144331                        NaN            NaN
#
#   daysOfPayablesOutstanding cashConversionCycle  ...  priceEarningsRatio  \
# 0                   140.603            -100.693  ...             2.11802
# 1                   147.857            -116.701  ...             2.82784
# 2                       NaN                 NaN  ...              5.8944
# 3                       NaN                 NaN  ...            -1.29065
# 4                       NaN                 NaN  ...           -0.124077
#
#    priceToFreeCashFlowsRatio  priceToOperatingCashFlowsRatio  \
# 0                   0.929941                        0.929941
# 1                     1.7228                          1.7228
# 2                    3.59988                         3.59988
# 3                    5.74714                         5.74714
# 4                    0.62956                         0.62956
#
#    priceCashFlowRatio priceEarningsToGrowthRatio  priceSalesRatio  \
# 0            0.929941                    3.01608         0.360444
# 1              1.7228                     3.7899         0.619248
# 2             3.59988                    7.14069         0.851208
# 3             5.74714                   -1.49527          1.29142
# 4             0.62956                  -0.134113         0.432688
#
#   dividendYield enterpriseValueMultiple priceFairValue  Year
# 0           NaN                 4.92373       0.325382  2019
# 1           NaN                 5.75903       0.799227  2018
# 2   0.000285957                  15.537         1.4837  2017
# 3   0.000385743                -6.41776        2.68953  2016
# 4      0.120239               -0.665779       0.435684  2015
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Merge Datasets

# %% [markdown]
# #### select dates

# %%
df_ratings['date'] = df_ratings['date'].astype('datetime64[ns]')
df_ratings['month_rating'] = df_ratings['date'].dt.month
df_ratings['year_change'] = [1 if x < 7 else 0 for x in df_ratings['month_rating']]
df_ratings['year'] = df_ratings['date'].dt.year

# %%
df_ratings['Year'] = df_ratings['year'] - df_ratings['year_change']

# %%
company_ratios = company_ratios.rename(columns = {'symbol':'Symbol'})

# %%
company_ratios['date'] = company_ratios['date'].astype('datetime64[ns]')
company_ratios['Year'] = company_ratios['date'].dt.year

# %%
df_ratings = pd.merge(df_ratings, company_ratios, on=['Symbol', 'Year'])

# %%
df_ratings.groupby('Rating').count()
# Out:
#         Rating Agency Name  Name  Rating Outlook  date_x  Clean_Name  Symbol  \
# Rating
# A                      854   854             625     854         854     854
# AA                     142   142             100     142         142     142
# AAA                     20    20              18      20          20      20
# B                      845   845             734     845         845     845
# BB                    1601  1601            1428    1601        1601    1601
# BBB                   1871  1871            1439    1871        1871    1871
# CC                      12    12               7      12          12      12
# CCC                     96    96              82      96          96      96
# D                        7     7               5       7           7       7
#
#         Sector  industry  month_rating  year_change  ...  priceToSalesRatio  \
# Rating                                               ...
# A          854       854           854          854  ...                688
# AA         142       142           142          142  ...                118
# AAA         20        20            20           20  ...                 17
# B          837       837           845          845  ...                738
# BB        1565      1565          1601         1601  ...               1431
# BBB       1853      1853          1871         1871  ...               1647
# CC          12        12            12           12  ...                  8
# CCC         96        96            96           96  ...                 84
# D            7         7             7            7  ...                  6
#
#         priceEarningsRatio  priceToFreeCashFlowsRatio  \
# Rating
# A                      682                        810
# AA                     112                        140
# AAA                     17                         19
# B                      725                        833
# BB                    1414                       1566
# BBB                   1624                       1824
# CC                       9                         12
# CCC                     80                         92
# D                        5                          6
#
#         priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# Rating
# A                                  697                 697
# AA                                 117                 117
# AAA                                 16                  16
# B                                  716                 716
# BB                                1404                1404
# BBB                               1641                1641
# CC                                   9                   9
# CCC                                 82                  82
# D                                    6                   6
#
#         priceEarningsToGrowthRatio  priceSalesRatio  dividendYield  \
# Rating
# A                              681              688            651
# AA                             112              118            103
# AAA                             17               17             16
# B                              719              738            314
# BB                            1397             1431            895
# BBB                           1612             1647           1410
# CC                               9                8              1
# CCC                             80               84             30
# D                                5                6              0
#
#         enterpriseValueMultiple  priceFairValue
# Rating
# A                           800             646
# AA                          141              94
# AAA                          20              17
# B                           839             705
# BB                         1586            1349
# BBB                        1809            1565
# CC                           12               9
# CCC                          94              83
# D                             6               6
#
# [9 rows x 67 columns]

# %%
df_ratings.to_csv (r'C:stocks_us/rating_dataframe.csv', index = False, header=True)
